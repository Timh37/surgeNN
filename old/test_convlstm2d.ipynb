# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np
from surgeNN.models import build_ConvLSTM2D_with_channels
from surgeNN.io import load_predictand,load_predictors
from surgeNN.utils import plot_loss_evolution, rmse, sequenced_dataset_from_dataset
from sklearn.metrics import confusion_matrix
from surgeNN.preprocessing import normalize_timeseries, get_train_test_val_idx
from target_relevance import TargetRelevance #first, in terminal, do->'mamba install kdepy'

# %% [markdown]
# Load in & preprocess data:

# %% [markdown]
# tg = 'den_helder-denhdr-nld-rws.csv' #site to predict
# temp_freq = 6 #hours
# predictand   = load_predictand('/home/jovyan/test_surge_models/input/t_tide_6h_anoms_deseasoned_predictands',tg) #open predictand csv (with mean seasonal cycle removed)
# #predictand   = load_predictand('/Users/timhermans/Documents/Github/surgeNN/input/predictands_6hourly',tg) #open predictand csv
# predictors   = load_predictors('/home/jovyan/test_surge_models/input/predictors_6hourly',tg,5) #open predictor xarray dataset
# predictors   = predictors.sel(time=slice('1980','2016')) #period for which we have hydrodynamic output as well
#
# # only use predictands at timesteps for which we have predictor values:
# predictand = predictand[(predictand['date']>=predictors.time.isel(time=0).values) & (predictand['date']<=predictors.time.isel(time=-1).values)]
#
# #preprocess predictors
# predictors = predictors.sel(time=predictand['date'].values)
# predictors = (predictors-predictors.mean(dim='time'))/predictors.std(dim='time',ddof=0) #normalize each variable in dataset
# my_predictors = np.stack((predictors.msl.values,predictors.w.values,predictors.u10.values,predictors.v10.values),axis=-1) #load into memory
#
# #preprocess observations
# predictand['surge'] = predictand['surge'].rolling(window=int(12/temp_freq) + 1,min_periods=1,center=True).mean() #in the literature, 12h-rolling means are used to account for spurious tidal peaks. Trying this out at the moment.
# predictand['surge'] = normalize_timeseries(predictand['surge']) #normalize predictands
# surge_obs = predictand['surge'].values #get values as array
#
# n_steps = 5 #number of timesteps included at and before the time of the observation
# batch_size = 128
#
# idx_train,idx_test,idx_val = get_train_test_val_idx(my_predictors,surge_obs,[.6,.2,.2],shuffle=False) #split data into training, validation and testing and get indices
#
# target_relevance = TargetRelevance(surge_obs[np.append(idx_train,idx_val)], alpha=4.5) #determine DenseLoss weights (apply KDE and compute inverse density weights)
# weights = target_relevance.eval(surge_obs[np.append(idx_train,idx_val)]).flatten()

# %%
#setttings
tg         = 'den_helder-denhdr-nld-rws.csv' #site to predict
temp_freq  = 3 #hours
n_steps    = 8 #number of timesteps at and before predictand to use predictors at
n_cells    = 5 #n x n grid cells around TG
batch_size = 128

predictand = load_predictand('/home/jovyan/test_surge_models/input/t_tide_'+str(temp_freq)+'h_anoms_deseasoned_predictands',tg) #open predictand csv
#predictand = load_predictand('/Users/timhermans/Documents/Github/surgeNN/input/predictands_6hourly',tg) #open predictand csv
predictors = load_predictors('/home/jovyan/test_surge_models/input/predictors_'+str(temp_freq)+'hourly',tg,n_cells) #open predictor xarray dataset
predictors = predictors.sel(time=slice('1980','2016')) #period for which we have hydrodynamic output as well
predictor_timesteps = predictors.time.to_dataframe() #store predictor timesteps in separate variable for later

# only use predictands at timesteps for which we have predictor values:
predictand = predictand[(predictand['date']>=predictors.time.isel(time=0).values) & (predictand['date']<=predictors.time.isel(time=-1).values)] 

#select predictors at predictand timesteps
predictors = predictors.sel(time=predictand['date'].values)
predictors = (predictors-predictors.mean(dim='time'))/predictors.std(dim='time',ddof=0) #normalize each variable in dataset
predictand['surge'] = predictand['surge'].rolling(window=5,min_periods=1,center=True).mean()
predictand['surge'] = normalize_timeseries(predictand['surge']) #normalize predictands

surge_obs = predictand['surge'].values #get values from dictionary

my_predictors = np.stack((predictors.msl.values,predictors.w.values,predictors.u10.values,predictors.v10.values),axis=-1) #load into memory

idx_train,idx_test,idx_val = get_train_test_val_idx(surge_obs,[.6,.2,.2],shuffle=False) #split data into training, validation and testing and get indices

#compute loss weights using DenseLoss method
target_relevance = TargetRelevance(surge_obs[np.append(idx_train,idx_val)], alpha=4)
weights = target_relevance.eval(surge_obs[np.append(idx_train,idx_val)]).flatten()

xx_train = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(my_predictors[idx_train,...]), n_steps, batch_size)
yy_train = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(surge_obs[idx_train][n_steps-1::]), 1, batch_size)
ww_train = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(weights[idx_train][n_steps-1::]), 1, batch_size) #test
zz_train = tf.data.Dataset.zip((xx_train,yy_train,ww_train)) #produce input dataset with DenseLoss weights
#zz_train = tf.data.Dataset.zip((xx_train,yy_train)) #produce input dataset without DenseLoss weights

xx_val = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(my_predictors[idx_val,...]), n_steps, batch_size)
yy_val = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(surge_obs[idx_val][n_steps-1::]), 1, batch_size)
ww_val = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(weights[idx_val][n_steps-1::]), 1, batch_size) #test
zz_val = tf.data.Dataset.zip((xx_val,yy_val,ww_val)) #produce input dataset with DenseLoss weights
#zz_val = tf.data.Dataset.zip((xx_val,yy_val)) #produce input dataset with DenseLoss weights

xx_test = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(my_predictors[idx_test,...]), n_steps, batch_size)
yy_test = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(surge_obs[idx_test][n_steps-1::]), 1, batch_size)
zz_test = tf.data.Dataset.zip((xx_test,yy_test))
# Out:
# WARNING:tensorflow:From /srv/conda/envs/notebook/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 2024-07-27 12:58:44.451591: W tensorflow/tsl/framework/bfc_allocator.cc:479] Allocator (GPU_0_bfc) ran out of memory trying to allocate 164.3KiB (rounded to 168448)requested by op _EagerConst
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-07-27 12:58:44.451796: W tensorflow/tsl/framework/bfc_allocator.cc:492] ********************************************************************************************xxxxxxxx
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[5], line 46
#      43 #zz_val = tf.data.Dataset.zip((xx_val,yy_val)) #produce input dataset with DenseLoss weights
#      45 xx_test = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(my_predictors[idx_test,...]), n_steps, batch_size)
# ---> 46 yy_test = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(surge_obs[idx_test][n_steps-1::]), 1, batch_size)
#      47 zz_test = tf.data.Dataset.zip((xx_test,yy_test))
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:818, in DatasetV2.from_tensor_slices(tensors, name)
#     815 # Loaded lazily due to a circular dependency (dataset_ops ->
#     816 # from_tensor_slices_op -> dataset_ops).
#     817 from tensorflow.python.data.ops import from_tensor_slices_op  # pylint: disable=g-import-not-at-top
# --> 818 return from_tensor_slices_op.from_tensor_slices(tensors, name)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/tensorflow/python/data/ops/from_tensor_slices_op.py:25, in from_tensor_slices(tensors, name)
#      24 def from_tensor_slices(tensors, name=None):
# ---> 25   return TensorSliceDataset(tensors, name=name)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/tensorflow/python/data/ops/from_tensor_slices_op.py:33, in TensorSliceDataset.__init__(self, element, is_files, name)
#      31 def __init__(self, element, is_files=False, name=None):
#      32   """See `Dataset.from_tensor_slices` for details."""
# ---> 33   element = structure.normalize_element(element)
#      34   batched_spec = structure.type_spec_from_value(element)
#      35   self._tensors = structure.to_batched_tensor_list(batched_spec, element)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/tensorflow/python/data/util/structure.py:130, in normalize_element(element, element_signature)
#     127       else:
#     128         dtype = getattr(spec, "dtype", None)
#     129         normalized_components.append(
# --> 130             ops.convert_to_tensor(t, name="component_%d" % i, dtype=dtype))
#     131 return nest.pack_sequence_as(pack_as, normalized_components)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/tensorflow/python/profiler/trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:1636, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1627       raise RuntimeError(
#    1628           _add_error_prefix(
#    1629               f"Conversion function {conversion_func!r} for type "
#    (...)
#    1632               f"actual = {ret.dtype.base_dtype.name}",
#    1633               name=name))
#    1635 if ret is None:
# -> 1636   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1638 if ret is NotImplemented:
#    1639   continue
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:48, in _default_conversion_function(***failed resolving arguments***)
#      46 def _default_conversion_function(value, dtype, name, as_ref):
#      47   del as_ref  # Unused.
# ---> 48   return constant_op.constant(value, dtype, name=name)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/tensorflow/python/framework/constant_op.py:267, in constant(value, dtype, shape, name)
#     170 @tf_export("constant", v1=[])
#     171 def constant(value, dtype=None, shape=None, name="Const"):
#     172   """Creates a constant tensor from a tensor-like object.
#     173
#     174   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     265     ValueError: if called on a symbolic tensor.
#     266   """
# --> 267   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     268                         allow_broadcast=True)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/tensorflow/python/framework/constant_op.py:279, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     277     with trace.Trace("tf.constant"):
#     278       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 279   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     281 g = ops.get_default_graph()
#     282 tensor_value = attr_value_pb2.AttrValue()
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/tensorflow/python/framework/constant_op.py:304, in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     302 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     303   """Creates a constant on the current device."""
# --> 304   t = convert_to_eager_tensor(value, ctx, dtype)
#     305   if shape is None:
#     306     return t
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/tensorflow/python/framework/constant_op.py:102, in convert_to_eager_tensor(value, ctx, dtype)
#     100     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101 ctx.ensure_initialized()
# --> 102 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.

# %% [markdown]
# #try to set everything below the mean also to the weight of the mean to make it less important to predict lower than average sea levels well
# weights[surge_obs[np.append(idx_train,idx_val)]<np.mean(surge_obs[np.append(idx_train,idx_val)])] = np.min(weights)
#
# #weights = weights/np.sum(weights)

# %%
plt.figure()
plt.scatter(surge_obs[np.append(idx_train,idx_val)],weights,s=2)
plt.axhline(y=0)
plt.ylabel('Loss weight')
plt.xlabel('Sea level [standard deviation]')
plt.title('DenseLoss loss weights')
# Out:
# Text(0.5, 1.0, 'DenseLoss loss weights')

# %% [markdown]
# Create generator datasets with sequences that don't fit into memory otherwise:

# %%
#xx_train=tuple([sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(predictors[k].values[idx_train,...]), n_steps, batch_size) for k in ['msl','w','u10','v10']]) #if passing variables separately
xx_train = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(my_predictors[idx_train,...]), n_steps, batch_size) #if passing variables together as channels
yy_train = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(surge_obs[idx_train][n_steps-1::]), 1, batch_size)
ww_train = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(weights[idx_train][n_steps-1::]), 1, batch_size)
zz_train = tf.data.Dataset.zip((xx_train,yy_train,ww_train))
#zz_train = tf.data.Dataset.zip((xx_train,yy_train))

#xx_val=tuple([sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(predictors[k].values[idx_val,...]), n_steps, batch_size) for k in ['msl','w','u10','v10']]) #if passing variables separately
xx_val = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(my_predictors[idx_val,...]), n_steps, batch_size) #if passing variables together as channels
yy_val = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(surge_obs[idx_val][n_steps-1::]), 1, batch_size)
ww_val = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(weights[idx_val][n_steps-1::]), 1, batch_size)
zz_val = tf.data.Dataset.zip((xx_val,yy_val,ww_val))
#zz_val = tf.data.Dataset.zip((xx_val,yy_val))

#xx_test=tuple([sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(predictors[k].values[idx_test,...]), n_steps, batch_size) for k in ['msl','w','u10','v10']]) #if passing variables separately
xx_test = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(my_predictors[idx_test,...]), n_steps, batch_size) #if passing variables together as channels
yy_test = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(surge_obs[idx_test][n_steps-1::]), 1, batch_size)
zz_test = tf.data.Dataset.zip((xx_test,yy_test))

# %% [markdown]
# Plot KDE weights:

# %% [markdown]
# ```python
# plt.figure()
# plt.scatter(surge_obs[np.append(idx_train,idx_val)],weights,s=2)
# plt.axhline(y=0)
# plt.ylabel('Loss weight')
# plt.xlabel('Sea level [standard deviation]')
# plt.title('DenseLoss (KDE)')
# ```

# %%
model = build_ConvLSTM2D_with_channels(1, 2, [32], [32,32], n_steps,20,20, 4, 'model0', .1, 1e-5, 'mae',l2=0.01)

# %%
history = model.fit(zz_train,epochs=40,validation_data=zz_val,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5,
                        restore_best_weights=True)])
# Out:
# Epoch 1/40
# 2024-07-15 10:30:55.496711: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel0/spatial_dropout2d/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-07-15 10:30:56.061942: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:85] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2024-07-15 10:30:56.063135: W tensorflow/compiler/xla/stream_executor/gpu/redzone_allocator.cc:318] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
#     247/Unknown - 21s 72ms/step - loss: 1.7402 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 23s 83ms/step - loss: 1.7402 - accuracy: 0.0000e+00 - val_loss: 1.5091 - val_accuracy: 0.0000e+00
# Epoch 2/40
# 246/247 [============================>.] - ETA: 0s - loss: 1.2320 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 20s 79ms/step - loss: 1.2300 - accuracy: 0.0000e+00 - val_loss: 0.8375 - val_accuracy: 0.0000e+00
# Epoch 3/40
# 246/247 [============================>.] - ETA: 0s - loss: 1.1048 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 1.1029 - accuracy: 0.0000e+00 - val_loss: 0.7344 - val_accuracy: 0.0000e+00
# Epoch 4/40
# 246/247 [============================>.] - ETA: 0s - loss: 1.0138 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 1.0121 - accuracy: 0.0000e+00 - val_loss: 0.6939 - val_accuracy: 0.0000e+00
# Epoch 5/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.9604 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.9588 - accuracy: 0.0000e+00 - val_loss: 0.6778 - val_accuracy: 0.0000e+00
# Epoch 6/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.9260 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.9244 - accuracy: 0.0000e+00 - val_loss: 0.6575 - val_accuracy: 0.0000e+00
# Epoch 7/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.9018 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.9002 - accuracy: 0.0000e+00 - val_loss: 0.6464 - val_accuracy: 0.0000e+00
# Epoch 8/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.8764 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.8749 - accuracy: 0.0000e+00 - val_loss: 0.6160 - val_accuracy: 0.0000e+00
# Epoch 9/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.8486 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.8471 - accuracy: 0.0000e+00 - val_loss: 0.6169 - val_accuracy: 0.0000e+00
# Epoch 10/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.8413 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.8398 - accuracy: 0.0000e+00 - val_loss: 0.6006 - val_accuracy: 0.0000e+00
# Epoch 11/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.8211 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.8196 - accuracy: 0.0000e+00 - val_loss: 0.5968 - val_accuracy: 0.0000e+00
# Epoch 12/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.8045 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.8030 - accuracy: 0.0000e+00 - val_loss: 0.5870 - val_accuracy: 0.0000e+00
# Epoch 13/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.7935 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.7920 - accuracy: 0.0000e+00 - val_loss: 0.5731 - val_accuracy: 0.0000e+00
# Epoch 14/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.7766 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.7751 - accuracy: 0.0000e+00 - val_loss: 0.5751 - val_accuracy: 0.0000e+00
# Epoch 15/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.7786 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.7772 - accuracy: 0.0000e+00 - val_loss: 0.5645 - val_accuracy: 0.0000e+00
# Epoch 16/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.7777 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.7762 - accuracy: 0.0000e+00 - val_loss: 0.5528 - val_accuracy: 0.0000e+00
# Epoch 17/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.7624 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.7610 - accuracy: 0.0000e+00 - val_loss: 0.5546 - val_accuracy: 0.0000e+00
# Epoch 18/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.7550 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.7536 - accuracy: 0.0000e+00 - val_loss: 0.5558 - val_accuracy: 0.0000e+00
# Epoch 19/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.7542 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.7527 - accuracy: 0.0000e+00 - val_loss: 0.5467 - val_accuracy: 0.0000e+00
# Epoch 20/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.7500 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.7486 - accuracy: 0.0000e+00 - val_loss: 0.5555 - val_accuracy: 0.0000e+00
# Epoch 21/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.7393 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.7379 - accuracy: 0.0000e+00 - val_loss: 0.5474 - val_accuracy: 0.0000e+00
# Epoch 22/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.7283 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.7269 - accuracy: 0.0000e+00 - val_loss: 0.5458 - val_accuracy: 0.0000e+00
# Epoch 23/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.7378 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.7364 - accuracy: 0.0000e+00 - val_loss: 0.5436 - val_accuracy: 0.0000e+00
# Epoch 24/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.7187 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.7174 - accuracy: 0.0000e+00 - val_loss: 0.5448 - val_accuracy: 0.0000e+00
# Epoch 25/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.7112 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.7098 - accuracy: 0.0000e+00 - val_loss: 0.5445 - val_accuracy: 0.0000e+00
# Epoch 26/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.7044 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.7031 - accuracy: 0.0000e+00 - val_loss: 0.5322 - val_accuracy: 0.0000e+00
# Epoch 27/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.7102 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.7088 - accuracy: 0.0000e+00 - val_loss: 0.5325 - val_accuracy: 0.0000e+00
# Epoch 28/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.7022 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.7009 - accuracy: 0.0000e+00 - val_loss: 0.5218 - val_accuracy: 0.0000e+00
# Epoch 29/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.6935 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.6921 - accuracy: 0.0000e+00 - val_loss: 0.5191 - val_accuracy: 0.0000e+00
# Epoch 30/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.6926 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.6913 - accuracy: 0.0000e+00 - val_loss: 0.5274 - val_accuracy: 0.0000e+00
# Epoch 31/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.6926 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.6912 - accuracy: 0.0000e+00 - val_loss: 0.5195 - val_accuracy: 0.0000e+00
# Epoch 32/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.6822 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.6809 - accuracy: 0.0000e+00 - val_loss: 0.5294 - val_accuracy: 0.0000e+00
# Epoch 33/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.6873 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.6860 - accuracy: 0.0000e+00 - val_loss: 0.5227 - val_accuracy: 0.0000e+00
# Epoch 34/40
# 246/247 [============================>.] - ETA: 0s - loss: 0.6829 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 247/247 [==============================] - 19s 78ms/step - loss: 0.6816 - accuracy: 0.0000e+00 - val_loss: 0.5466 - val_accuracy: 0.0000e+00

# %%
surge_cnn_test = model.predict(xx_test,verbose=0).flatten() #if using stacked instead of list of predictor input

# %% [markdown]
# If using list of predictors as input:
# ```python
# surge_cnn_test = model.predict(tf.data.Dataset.zip((xx_test, )),verbose=0).flatten()
# ```

# %%
f = plot_loss_evolution(history) #plot training loss

### do some evaluation
threshold_pct = 98 #percentile of storm surge data to look at

surge_obs_test = surge_obs[idx_test][n_steps-1::]
threshold_value = np.percentile(surge_obs[idx_test][n_steps-1::],threshold_pct) #threshold value

surge_obs_test_exceedances = (surge_obs[idx_test][n_steps-1::]>=threshold_value).flatten() #find where storm surges exceed threshold (extremes), for observations
surge_cnn_test_exceedances = (surge_cnn_test>=threshold_value).flatten() #find where storm surges exceed threshold (extremes), for predictions with CNN

print('---CNN---')
print('bulk correlation r='+str(np.corrcoef(surge_cnn_test,surge_obs_test)[0][1]))
print('bulk RMSE='+str(rmse(surge_cnn_test,surge_obs_test)))
print('Confusion matrix exceedances above {0}th percentile:'.format(threshold_pct))
print(confusion_matrix(surge_obs_test_exceedances,surge_cnn_test_exceedances))

print('Correlation at timesteps where observations above {0}th percentile:'.format(threshold_pct))
print('r=' + str(np.corrcoef(surge_cnn_test[surge_obs_test_exceedances],surge_obs_test[surge_obs_test_exceedances])[0][1]))
print('RMSE at timesteps where observations above {0}th percentile:'.format(threshold_pct))
print('RMSE=' + str(rmse(surge_cnn_test[surge_obs_test_exceedances],surge_obs_test[surge_obs_test_exceedances])))
# Out:
# ---CNN---
# bulk correlation r=0.796125446478651
# bulk RMSE=0.6694310782994001
# Confusion matrix exceedances above 98th percentile:
# [[10167   137]
#  [   40   171]]
# Correlation at timesteps where observations above 98th percentile:
# r=0.7750196054807142
# RMSE at timesteps where observations above 98th percentile:
# RMSE=0.5627537365370271

# %% [markdown]
# Some prior results:
#
# a=3
# ---CNN---
# bulk correlation r=0.8146921014924382
# bulk RMSE=0.6628850423328566
# Confusion matrix exceedances above 98th percentile:
# [[20416   195]
#  [  120   301]]
# Correlation at timesteps where observations above 98th percentile:
# r=0.833167212453055
# RMSE at timesteps where observations above 98th percentile:
# RMSE=0.6235710888040278
#
# a=4
# ---CNN---
# bulk correlation r=0.8336205641066491
# bulk RMSE=0.6346390808066679
# Confusion matrix exceedances above 98th percentile:
# [[20251   360]
#  [   64   357]]
# Correlation at timesteps where observations above 98th percentile:
# r=0.8399073757669463
# RMSE at timesteps where observations above 98th percentile:
# RMSE=0.5186600518141902
#
# ---CoDEC---
# bulk correlation r=0.9271770349293676
# bulk RMSE=0.3521273103012632
# Confusion matrix exceedances above 98th percentile:
# [[20508   103]
#  [   70   351]]
# Correlation at timesteps where observations above 98th percentile:
# r=0.9168742281823624
# RMSE at timesteps where observations above 98th percentile:
# RMSE=0.39142061574991016
#
# kde weighting, rolling mean window of 5, 8 lag, 128 batch size, model = test_model(1, 2, [32], [32,32], n_steps,20,20, 4, 'model0', .1, 1e-5, 'mae',l2=0.01)

# %%
plt.figure()
plt.plot(surge_obs[idx_test][n_steps-1::][surge_obs_test_exceedances],label='Observed')
plt.plot(surge_cnn_test[surge_obs_test_exceedances],label='Conv2DLSTM')
plt.axhline(y=threshold_value)
plt.legend()
plt.ylabel('Sea level [standard deviation]')
plt.xlabel('Observed exceedance #')
plt.title(tg+' (test split) True Positives & False Negatives')
plt.ylim([1,8])
            

plt.figure()
plt.plot(surge_obs[idx_test][n_steps-1::],label='Observed')
plt.plot(surge_cnn_test,label='Conv2DLSTM')
plt.axhline(y=threshold_value)
plt.ylabel('Sea level [standard deviation]')
plt.xlabel('Observation #')
plt.title(tg+' (test split)')
plt.legend()

# %%
plt.figure()
plt.plot(surge_obs[idx_test][n_steps-1::][surge_cnn_test_exceedances * (surge_obs_test_exceedances==0)],label='Observed')
plt.plot(surge_cnn_test[surge_cnn_test_exceedances * (surge_obs_test_exceedances==0)],label='Conv2DLSTM')
plt.axhline(y=threshold_value)
plt.legend()
plt.ylabel('Sea level [standard deviation]')
plt.xlabel('Observed exceedance #')
plt.title(tg+' (test split) False positives')
plt.ylim([-2,8])
# Out:
# (-2.0, 8.0)

# %% [markdown]
# Evaluate the hydrodynamic model output samples the same timesteps as the predictands:

# %%
surge_codec = xr.open_dataset('/home/jovyan/test_surge_models/CoDEC_ERA5_at_gesla3_tgs_eu_hourly_anoms.nc')
surge_codec = surge_codec.sel(time=predictand['date'].values)
surge_codec['surge'] = surge_codec['surge'].rolling(time=5,min_periods=1,center=True).mean()
surge_codec['surge'] = (surge_codec['surge'] - surge_codec['surge'].mean(dim='time'))/surge_codec['surge'].std(dim='time',ddof=0) #normalize
surge_codec_test = surge_codec.sel(tg=tg).sel(time=predictand['date'].values[idx_test][n_steps-1::]).surge.values #select test timesteps
surge_codec_test_exceedances = (surge_codec_test>=threshold_value).flatten() #find where exceeding threshold
 
print('---CoDEC---')
print('bulk correlation r='+str(np.corrcoef(surge_codec_test,surge_obs_test)[0][1]))
print('bulk RMSE='+str(rmse(surge_codec_test,surge_obs_test)))
print('Confusion matrix exceedances above {0}th percentile:'.format(threshold_pct))
print(confusion_matrix(surge_obs_test_exceedances,surge_codec_test_exceedances))

print('Correlation at timesteps where observations above {0}th percentile:'.format(threshold_pct))
print('r=' + str(np.corrcoef(surge_codec_test[surge_obs_test_exceedances],surge_obs_test[surge_obs_test_exceedances])[0][1]))
print('RMSE at timesteps where observations above {0}th percentile:'.format(threshold_pct))
print('RMSE=' + str(rmse(surge_codec_test[surge_obs_test_exceedances],surge_obs_test[surge_obs_test_exceedances])))
# Out:
# ---CoDEC---
# bulk correlation r=0.9108163806621088
# bulk RMSE=0.3858848325807934
# Confusion matrix exceedances above 99th percentile:
# [[10375    34]
#  [   21    85]]
# Correlation at timesteps where observations above 99th percentile:
# r=0.8839857740127516
# RMSE at timesteps where observations above 99th percentile:
# RMSE=0.422800981903512

# %%
plt.figure()
plt.plot(surge_obs[idx_test][n_steps-1::][surge_obs_test_exceedances],label='Observed')
plt.plot(surge_codec_test[surge_obs_test_exceedances],label='GTSM')
plt.axhline(y=threshold_value)
plt.legend()
plt.ylabel('Sea level [standard deviation]')
plt.xlabel('Observed exceedance #')
plt.title(tg+' (test split)')
plt.ylim([1,8])
# Out:
# (1.0, 8.0)

# %%
3*2*2*3*3
# Out:
# 108

# %%
3*2*2*3*3 * 11
# Out:
# 1188

# %%
3*2*2*2*3*3*11
# Out:
# 2376
