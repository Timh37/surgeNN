# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np
from sklearn.metrics import confusion_matrix
from keras.layers import Input
from surgeNN.models import train_mlr,predict_mlr, build_Conv3D_with_channels, build_Conv3D_per_variable
from surgeNN.io import load_predictand,load_predictors
from surgeNN.utils import plot_loss_evolution, get_train_test_val_idx, normalize_timeseries, rmse, sequenced_dataset_from_dataset
from scipy import stats
from keras import Sequential
from target_relevance import TargetRelevance #terminal->'mamba install kdepy' works
# Out:
# 2024-05-06 10:09:22.904153: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Load in & preprocess data:

# %%
tg = 'den_helder-denhdr-nld-rws.csv' #site to predict
predictand   = load_predictand('/home/jovyan/test_surge_models/input/t_tide_3h_anoms_deseasoned_predictands',tg) #open predictand csv (with mean seasonal cycle removed)
#predictand   = load_predictand('/Users/timhermans/Documents/Github/surgeNN/input/predictands_6hourly',tg) #open predictand csv
predictors   = load_predictors('/home/jovyan/test_surge_models/input/predictors_3hourly',tg,5) #open predictor xarray dataset
predictors   = predictors.sel(time=slice('1980','2016')) #period for which we have hydrodynamic output as well

# only use predictands at timesteps for which we have predictor values:
predictand = predictand[(predictand['date']>=predictors.time.isel(time=0).values) & (predictand['date']<=predictors.time.isel(time=-1).values)] 

#preprocess predictors
predictors = predictors.sel(time=predictand['date'].values)
predictors = (predictors-predictors.mean(dim='time'))/predictors.std(dim='time',ddof=0) #normalize each variable in dataset
my_predictors = np.stack((predictors.msl.values,predictors.w.values,predictors.u10.values,predictors.v10.values),axis=-1) #load into memory

#preprocess observations
predictand['surge'] = predictand['surge'].rolling(window=5,min_periods=1,center=True).mean() #in the literature, 12h-rolling means are used to account for spurious tidal peaks. Trying this out at the moment.
predictand['surge'] = normalize_timeseries(predictand['surge']) #normalize predictands
surge_obs = predictand['surge'].values #get values as array

target_relevance = TargetRelevance(surge_obs[np.append(idx_train,idx_val)], alpha=4) #determine DenseLoss weights (apply KDE and compute inverse density weights)
weights = target_relevance.eval(surge_obs[np.append(idx_train,idx_val)]).flatten()

n_steps = 3 #number of timesteps included at and before the time of the observation
batch_size = 128

idx_train,idx_test,idx_val = get_train_test_val_idx(my_predictors,surge_obs,[.6,.2,.2],shuffle=False) #split data into training, validation and testing and get indices

# %% [markdown]
# Create generator datasets with sequences that don't fit into memory otherwise:

# %%
xx_train=tuple([sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(predictors[k].values[idx_train,...]), n_steps, batch_size) for k in ['msl','w','u10','v10']])
#xx_train = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(my_predictors[idx_train,...]), n_steps, batch_size)
yy_train = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(surge_obs[idx_train][n_steps-1::]), 1, batch_size)
ww_train = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(weights[idx_train][n_steps-1::]), 1, batch_size) #test
zz_train = tf.data.Dataset.zip((xx_train,yy_train,ww_train))

xx_val=tuple([sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(predictors[k].values[idx_val,...]), n_steps, batch_size) for k in ['msl','w','u10','v10']])
#xx_val = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(my_predictors[idx_val,...]), n_steps, batch_size)
yy_val = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(surge_obs[idx_val][n_steps-1::]), 1, batch_size)
ww_val = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(weights[idx_val][n_steps-1::]), 1, batch_size) #test
zz_val = tf.data.Dataset.zip((xx_val,yy_val,ww_val))

xx_test=tuple([sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(predictors[k].values[idx_test,...]), n_steps, batch_size) for k in ['msl','w','u10','v10']])
#xx_test = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(my_predictors[idx_test,...]), n_steps, batch_size)
yy_test = sequenced_dataset_from_dataset(tf.data.Dataset.from_tensor_slices(surge_obs[idx_test][n_steps-1::]), 1, batch_size)
zz_test = tf.data.Dataset.zip((xx_test,yy_test))
# Out:
# TargetRelevance alpha: 8
# Using Silverman Bandwidth 0.11164234224478356
# WARNING:tensorflow:From /srv/conda/envs/notebook/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %%
model = build_Conv3D_per_variable(1, 3, [32], [32,32,32], n_steps,20,20, 4, 'model0', .2, 1e-6, 'mae',l2=0.01)

# %%
history = model.fit(zz_train,epochs=70,validation_data=zz_val,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5,
                        restore_best_weights=True)])
# Out:
# Epoch 1/70
# 2024-05-06 10:09:41.579515: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:85] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2024-05-06 10:09:41.580608: W tensorflow/compiler/xla/stream_executor/gpu/redzone_allocator.cc:318] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
#     493/Unknown - 12s 18ms/step - loss: 2.6667 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 15s 23ms/step - loss: 2.6664 - accuracy: 0.0000e+00 - val_loss: 1.1391 - val_accuracy: 0.0000e+00
# Epoch 2/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.8940 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.8938 - accuracy: 0.0000e+00 - val_loss: 1.0862 - val_accuracy: 0.0000e+00
# Epoch 3/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.7067 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.7065 - accuracy: 0.0000e+00 - val_loss: 1.0214 - val_accuracy: 0.0000e+00
# Epoch 4/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.5976 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.5974 - accuracy: 0.0000e+00 - val_loss: 0.9612 - val_accuracy: 0.0000e+00
# Epoch 5/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.5474 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.5473 - accuracy: 0.0000e+00 - val_loss: 0.9084 - val_accuracy: 0.0000e+00
# Epoch 6/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.5186 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.5184 - accuracy: 0.0000e+00 - val_loss: 0.8790 - val_accuracy: 0.0000e+00
# Epoch 7/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.4760 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.4758 - accuracy: 0.0000e+00 - val_loss: 0.8570 - val_accuracy: 0.0000e+00
# Epoch 8/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.4312 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.4310 - accuracy: 0.0000e+00 - val_loss: 0.8482 - val_accuracy: 0.0000e+00
# Epoch 9/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.4168 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.4166 - accuracy: 0.0000e+00 - val_loss: 0.8334 - val_accuracy: 0.0000e+00
# Epoch 10/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.3832 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.3830 - accuracy: 0.0000e+00 - val_loss: 0.8151 - val_accuracy: 0.0000e+00
# Epoch 11/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.3749 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.3747 - accuracy: 0.0000e+00 - val_loss: 0.8044 - val_accuracy: 0.0000e+00
# Epoch 12/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.3719 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.3718 - accuracy: 0.0000e+00 - val_loss: 0.7980 - val_accuracy: 0.0000e+00
# Epoch 13/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.3550 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.3548 - accuracy: 0.0000e+00 - val_loss: 0.7865 - val_accuracy: 0.0000e+00
# Epoch 14/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.3327 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.3325 - accuracy: 0.0000e+00 - val_loss: 0.7872 - val_accuracy: 0.0000e+00
# Epoch 15/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.3231 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.3229 - accuracy: 0.0000e+00 - val_loss: 0.7779 - val_accuracy: 0.0000e+00
# Epoch 16/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.3256 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.3254 - accuracy: 0.0000e+00 - val_loss: 0.7774 - val_accuracy: 0.0000e+00
# Epoch 17/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.3092 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.3090 - accuracy: 0.0000e+00 - val_loss: 0.7651 - val_accuracy: 0.0000e+00
# Epoch 18/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.3006 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.3004 - accuracy: 0.0000e+00 - val_loss: 0.7717 - val_accuracy: 0.0000e+00
# Epoch 19/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.2901 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.2899 - accuracy: 0.0000e+00 - val_loss: 0.7581 - val_accuracy: 0.0000e+00
# Epoch 20/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.2751 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.2749 - accuracy: 0.0000e+00 - val_loss: 0.7502 - val_accuracy: 0.0000e+00
# Epoch 21/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.2973 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.2971 - accuracy: 0.0000e+00 - val_loss: 0.7487 - val_accuracy: 0.0000e+00
# Epoch 22/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.2565 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.2563 - accuracy: 0.0000e+00 - val_loss: 0.7391 - val_accuracy: 0.0000e+00
# Epoch 23/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.2527 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.2525 - accuracy: 0.0000e+00 - val_loss: 0.7306 - val_accuracy: 0.0000e+00
# Epoch 24/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.2545 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.2543 - accuracy: 0.0000e+00 - val_loss: 0.7229 - val_accuracy: 0.0000e+00
# Epoch 25/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.2521 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.2519 - accuracy: 0.0000e+00 - val_loss: 0.7200 - val_accuracy: 0.0000e+00
# Epoch 26/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.2250 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.2248 - accuracy: 0.0000e+00 - val_loss: 0.7154 - val_accuracy: 0.0000e+00
# Epoch 27/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.2337 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.2336 - accuracy: 0.0000e+00 - val_loss: 0.7143 - val_accuracy: 0.0000e+00
# Epoch 28/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.2265 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.2264 - accuracy: 0.0000e+00 - val_loss: 0.7132 - val_accuracy: 0.0000e+00
# Epoch 29/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.2187 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.2185 - accuracy: 0.0000e+00 - val_loss: 0.7055 - val_accuracy: 0.0000e+00
# Epoch 30/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.1820 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.1819 - accuracy: 0.0000e+00 - val_loss: 0.7070 - val_accuracy: 0.0000e+00
# Epoch 31/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.1919 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.1917 - accuracy: 0.0000e+00 - val_loss: 0.7090 - val_accuracy: 0.0000e+00
# Epoch 32/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.2072 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.2070 - accuracy: 0.0000e+00 - val_loss: 0.6997 - val_accuracy: 0.0000e+00
# Epoch 33/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.1900 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.1898 - accuracy: 0.0000e+00 - val_loss: 0.7042 - val_accuracy: 0.0000e+00
# Epoch 34/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.1664 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.1663 - accuracy: 0.0000e+00 - val_loss: 0.6991 - val_accuracy: 0.0000e+00
# Epoch 35/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.1873 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.1871 - accuracy: 0.0000e+00 - val_loss: 0.6970 - val_accuracy: 0.0000e+00
# Epoch 36/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.1731 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.1729 - accuracy: 0.0000e+00 - val_loss: 0.6975 - val_accuracy: 0.0000e+00
# Epoch 37/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.1589 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.1587 - accuracy: 0.0000e+00 - val_loss: 0.6925 - val_accuracy: 0.0000e+00
# Epoch 38/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.1600 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.1598 - accuracy: 0.0000e+00 - val_loss: 0.6852 - val_accuracy: 0.0000e+00
# Epoch 39/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.1797 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.1795 - accuracy: 0.0000e+00 - val_loss: 0.6812 - val_accuracy: 0.0000e+00
# Epoch 40/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.1515 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.1513 - accuracy: 0.0000e+00 - val_loss: 0.6758 - val_accuracy: 0.0000e+00
# Epoch 41/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.1392 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.1391 - accuracy: 0.0000e+00 - val_loss: 0.6757 - val_accuracy: 0.0000e+00
# Epoch 42/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.1554 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.1553 - accuracy: 0.0000e+00 - val_loss: 0.6824 - val_accuracy: 0.0000e+00
# Epoch 43/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.1466 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.1465 - accuracy: 0.0000e+00 - val_loss: 0.6790 - val_accuracy: 0.0000e+00
# Epoch 44/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.1141 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.1139 - accuracy: 0.0000e+00 - val_loss: 0.6803 - val_accuracy: 0.0000e+00
# Epoch 45/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.1405 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.1403 - accuracy: 0.0000e+00 - val_loss: 0.6831 - val_accuracy: 0.0000e+00
# Epoch 46/70
# 493/494 [============================>.] - ETA: 0s - loss: 1.1260 - accuracy: 0.0000e+00WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 494/494 [==============================] - 10s 21ms/step - loss: 1.1258 - accuracy: 0.0000e+00 - val_loss: 0.6864 - val_accuracy: 0.0000e+00

# %% [markdown]
# surge_cnn_test = model.predict(xx_test,verbose=0).flatten()

# %%
surge_cnn_test = model.predict(tf.data.Dataset.zip((xx_test, )),verbose=0).flatten() #if using list of predictors as input

# %%
f = plot_loss_evolution(history) #plot training loss

### do some evaluation
threshold_pct = 98 #percentile of storm surge data to look at

surge_obs_test = surge_obs[idx_test][n_steps-1::] #surge_obs[idx_test]
threshold_value = np.percentile(surge_obs[idx_test][n_steps-1::],threshold_pct) #threshold value

surge_obs_test_exceedances = (surge_obs[idx_test][n_steps-1::]>=threshold_value).flatten() #find where storm surges exceed threshold (extremes), for observations
surge_cnn_test_exceedances = (surge_cnn_test>=threshold_value).flatten() #find where storm surges exceed threshold (extremes), for predictions with CNN

print('---CNN---')
print('bulk correlation r='+str(np.corrcoef(surge_cnn_test,surge_obs_test)[0][1]))
print('bulk RMSE='+str(rmse(surge_cnn_test,surge_obs_test)))
print('Confusion matrix exceedances above {0}th percentile:'.format(threshold_pct))
print(confusion_matrix(surge_obs_test_exceedances,surge_cnn_test_exceedances))

print('Correlation at timesteps where observations above {0}th percentile:'.format(threshold_pct))
print('r=' + str(np.corrcoef(surge_cnn_test[surge_obs_test_exceedances],surge_obs_test[surge_obs_test_exceedances])[0][1]))
print('RMSE at timesteps where observations above {0}th percentile:'.format(threshold_pct))
print('RMSE=' + str(rmse(surge_cnn_test[surge_obs_test_exceedances],surge_obs_test[surge_obs_test_exceedances])))
# Out:
# ---CNN---
# bulk correlation r=0.8027147604363576
# bulk RMSE=0.5924253087595672
# Confusion matrix exceedances above 98th percentile:
# [[20220   396]
#  [   78   343]]
# Correlation at timesteps where observations above 98th percentile:
# r=0.6222814183164787
# RMSE at timesteps where observations above 98th percentile:
# RMSE=0.7775132631788387

# %% [markdown]
# ---CNN---
# bulk correlation r=0.8146921014924382
# bulk RMSE=0.6628850423328566
# Confusion matrix exceedances above 98th percentile:
# [[20416   195]
#  [  120   301]]
# Correlation at timesteps where observations above 98th percentile:
# r=0.833167212453055
# RMSE at timesteps where observations above 98th percentile:
# RMSE=0.6235710888040278
#
# ---CoDEC---
# bulk correlation r=0.9271770349293676
# bulk RMSE=0.3521273103012632
# Confusion matrix exceedances above 98th percentile:
# [[20508   103]
#  [   70   351]]
# Correlation at timesteps where observations above 98th percentile:
# r=0.9168742281823624
# RMSE at timesteps where observations above 98th percentile:
# RMSE=0.39142061574991016
#
# alpha=3, kde weighting, rolling mean window of 5, 8 lag, 128 batch size, model = test_model(1, 2, [32], [32,32], n_steps,20,20, 4, 'model0', .1, 1e-5, 'mae',l2=0.01)

# %%
plt.figure()
plt.plot(surge_obs[idx_test][n_steps-1::][surge_obs_test_exceedances],label='Observed')
plt.plot(surge_cnn_test[surge_obs_test_exceedances],label='Conv2DLSTM')
plt.axhline(y=threshold_value)
plt.legend()
plt.ylabel('Sea level [standard deviation]')
plt.xlabel('Observed exceedance #')
plt.title(tg+' (test split) True Positives & False Negatives')
plt.ylim([1,8])
            

plt.figure()
plt.plot(surge_obs[idx_test][n_steps-1::],label='Observed')
plt.plot(surge_cnn_test,label='Conv2DLSTM')
plt.axhline(y=threshold_value)
plt.ylabel('Sea level [standard deviation]')
plt.xlabel('Observation #')
plt.title(tg+' (test split)')
plt.legend()

# %%
plt.figure()
plt.plot(surge_obs[idx_test][n_steps-1::][surge_cnn_test_exceedances * (surge_obs_test_exceedances==0)],label='Observed')
plt.plot(surge_cnn_test[surge_cnn_test_exceedances * (surge_obs_test_exceedances==0)],label='Conv2DLSTM')
plt.axhline(y=threshold_value)
plt.legend()
plt.ylabel('Sea level [standard deviation]')
plt.xlabel('Observed exceedance #')
plt.title(tg+' (test split) False positives')
plt.ylim([-2,8])
# Out:
# (-2.0, 8.0)

# %%
surge_codec = xr.open_dataset('/home/jovyan/test_surge_models/CoDEC_ERA5_at_gesla3_tgs_eu_hourly_anoms.nc')
surge_codec = surge_codec.sel(time=predictand['date'].values)
surge_codec['surge'] = surge_codec['surge'].rolling(time=5,min_periods=1,center=True).mean()
surge_codec['surge'] = (surge_codec['surge'] - surge_codec['surge'].mean(dim='time'))/surge_codec['surge'].std(dim='time',ddof=0) #normalize
surge_codec_test = surge_codec.sel(tg=tg).sel(time=predictand['date'].values[idx_test][n_steps-1::]).surge.values #select test timesteps
surge_codec_test_exceedances = (surge_codec_test>=threshold_value).flatten() #find where exceeding threshold
 
print('---CoDEC---')
print('bulk correlation r='+str(np.corrcoef(surge_codec_test,surge_obs_test)[0][1]))
print('bulk RMSE='+str(rmse(surge_codec_test,surge_obs_test)))
print('Confusion matrix exceedances above {0}th percentile:'.format(threshold_pct))
print(confusion_matrix(surge_obs_test_exceedances,surge_codec_test_exceedances))

print('Correlation at timesteps where observations above {0}th percentile:'.format(threshold_pct))
print('r=' + str(np.corrcoef(surge_codec_test[surge_obs_test_exceedances],surge_obs_test[surge_obs_test_exceedances])[0][1]))
print('RMSE at timesteps where observations above {0}th percentile:'.format(threshold_pct))
print('RMSE=' + str(rmse(surge_codec_test[surge_obs_test_exceedances],surge_obs_test[surge_obs_test_exceedances])))
# Out:
# ---CoDEC---
# bulk correlation r=0.9271770349293676
# bulk RMSE=0.3521273103012632
# Confusion matrix exceedances above 98th percentile:
# [[20508   103]
#  [   70   351]]
# Correlation at timesteps where observations above 98th percentile:
# r=0.9168742281823624
# RMSE at timesteps where observations above 98th percentile:
# RMSE=0.39142061574991016

# %%
plt.figure()
plt.plot(surge_obs[idx_test][n_steps-1::][surge_obs_test_exceedances],label='Observed')
plt.plot(surge_codec_test[surge_obs_test_exceedances],label='GTSM')
plt.axhline(y=threshold_value)
plt.legend()
plt.ylabel('Sea level [standard deviation]')
plt.xlabel('Observed exceedance #')
plt.title(tg+' (test split)')
plt.ylim([1,8])
# Out:
# (1.0, 8.0)
