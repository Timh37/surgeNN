# %%
import tensorflow as tf
import xarray as xr
import fnmatch
import numpy as np
import os
import sys
import keras
from surgeNN import io, preprocessing
from surgeNN.io import train_predict_output_to_ds, setup_output_dirs, add_loss_to_output
#from surgeNN.denseLoss import get_denseloss_weights #if starting with a clean environment, first, in terminal, do->'mamba install kdepy'
from surgeNN.evaluation import add_error_metrics_to_prediction_ds,rmse
from surgeNN.models import build_LSTM_stacked, build_ConvLSTM2D_with_channels
from surgeNN.losses import gevl,exp_negexp_mse,obs_squared_weighted_mse, obs_weighted_mse
from tqdm import tqdm
import itertools
import random
import datetime

import gc #callback to clean up garbage after each epoch, not sure if strictly necessary (usage: callbacks = [GC_Callback()])
class GC_Callback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        gc.collect()
        
def train_and_predict(model_architecture,loss_function,hyperparam_options,
                      split_fractions,strat_metric,strat_start_month,strat_seed,tgs,n_runs,n_iterations,n_epochs,patience,
                      predictor_path,predictor_vars,predictor_degrees,predictand_path,temp_freq,output_dir,store_model):
    '''
    Execute model training and prediction and evaluation on test split. Uses a stratified splitting scheme.
    
    Input:
        model_architecture:  neural network type to use STR: ['lstm','convlstm']
        loss function:       dictionary with a key containing the name of the loss function, and a value containing the loss function (tensorflow default or custom) [DICT: {STR:STR or func}]
        hyperparam_options:  length 10 list of vectors containing options for each hyperparameter in the order: 
                             [[batch_size],[n_steps],[n_layers],[n_layer_units],[n_dense_layers],[n_dense_layer_units],[dropout_rate],[learning_rate],[l1],[dl_alpha]] 
        split_fractions:     list of split fractions in the order [train,test,val], sum must be 1
        strat_metric:        metric based on which to stratify years (annual maximum or a percentile) ['amax' OR STR '<float>pct']
        strat_start_month:   starting month of each year for stratified sampling, from 1 to 12 [int]
        tgs:                 tide gauges to train for [list]
        strat_seed:          seed to control randomness in the stratified sampling scheme [int]
        n_runs:              number of runs with different hyperparameters to do [int]
        n_iterations:        number of repetitions to run each setting with [int]
        n_epochs:            maximum number of epochs to train with [int]
        patience:            patience parameter for early stopping [int]
        predictor_path:      path to load predictor data from (must point to directories organized per temporal frequency) [str]
        predictor_vars:      predictor variables to use [list]
        predictor_degrees:   number of degrees of predictors around tide gauge to use [int/float]
        predictand_path:     path to load predictand data from (must point to directories organized per temporal frequency) [str]
        temp_freq: temporal  hourly frequency of input data to use [int]
        output_dir:          directory to store models and model performance to [str]
        store_models:        boolean indicating whether to output Tensorflow models [True/False]
        
    Output: 
        out_ds: xarray dataset containing the model settings, predictions and performance
    '''
    setup_output_dirs(output_dir,store_model,model_architecture)
    
    lf_name = list(loss_function.keys())[0]
    lf = list(loss_function.values())[0]
    
    try:
        lf = eval(lf)
    except:
        pass
        
    for tg in tqdm(tgs): #loop over TGs:
        
        ### (1) Load & prepare input data
        n_cells = int(predictor_degrees * (4/1)) #determine how many grid cells around TG to use (era5 resolution = 0.25 degree)
        
        predictors = io.Predictor(predictor_path)
        predictors.open_dataset(tg,predictor_vars,n_cells)
        '''
        time = predictors.data.time
        where_diff_not_3h = np.where(np.diff(predictors.data.time) !=  datetime.timedelta(seconds=10800))[0] #01-01-2015 00:00:00 is missing, but also in predictand data -> not an issue?

        newtime = np.hstack([time.values,time.values[-1]])
        newtime[0:where_diff_not_3h+1] = time.values[0:where_diff_not_3h+1]
        newtime[where_diff_not_3h+2::] = time.values[where_diff_not_3h+1::]
        newtime[where_diff_not_3h+1] = newtime[where_diff_not_3h+1] - datetime.timedelta(seconds=10800)

        predictors.data = predictors.data.reindex(time=newtime,method='ffill')
        '''
        predictors.subtract_annual_means()
        predictors.deseasonalize()
 
        predictand = io.Predictand(predictand_path)
        predictand.open_dataset(tg)
        #predictand.trim_dates(predictors.data.time.isel(time=0).values,predictors.data.time.isel(time=-1).values) #timesteps should align after working out stretching by Deltares
        predictand.deseasonalize()
        #predictand.resample_fillna(str(temp_freq)+'h') #not applicable here as the stretched timesteps aren't regularly spaced like in the observations in case of HadGEM3
    
        predictors.data['time'] = predictand.data.date.values #replace the original 360day calendar with the stretched timesteps that the predictands were selected at
        
        ### (2) Configure sets of hyperparameters to run with
        all_settings = list(itertools.product(*hyperparam_options))
        n_settings = len(all_settings)

        if n_runs<n_settings:
            selected_settings = random.sample(all_settings, n_runs)
        else:
            selected_settings = all_settings
        
        ### (3) Execute training & evaluation (n_iterations * n_runs times):
        for it in np.arange(n_iterations): #for each iteration
            tg_datasets = [] #list to store output
            
            for i,these_settings in enumerate(selected_settings): #for each set of hyperparameters
                
                this_batch_size,this_n_steps,this_n_convlstm,this_n_convlstm_units,this_n_dense,this_n_dense_units,this_dropout,this_lr,this_l2,this_dl_alpha = these_settings #pick hyperparameters for this run
 
                #generate train, validation and test splits & prepare input for model
                model_input = preprocessing.trainingInput(predictors,predictand)
                if model_architecture == 'lstm':
                    model_input.stack_predictor_coords()
                    
                model_input.split_stratified(split_fractions,this_n_steps,strat_start_month,strat_seed,strat_metric)
                y_train_mean,y_train_sd = model_input.standardize()
        
                model_input.compute_denseloss_weights(this_dl_alpha) #generate the Denseloss weights for each split
               
                x_train,y_train,w_train = model_input.get_windowed_filtered_np_input('train',this_n_steps) #generate input for neural network model
                x_val,y_val,w_val       = model_input.get_windowed_filtered_np_input('val',this_n_steps)
                x_test,y_test,w_test    = model_input.get_windowed_filtered_np_input('test',this_n_steps)

                o_train,o_val,o_test = [model_input.y_train_sd * k + model_input.y_train_mean for k in [y_train,y_val,y_test]] #back-transform observations

                #build model
                if model_architecture == 'convlstm':
                    model = build_ConvLSTM2D_with_channels(this_n_convlstm, this_n_dense,(np.ones(this_n_convlstm)*this_n_convlstm_units).astype(int), 
                                              (np.ones(this_n_dense)*this_n_dense_units).astype(int),this_n_steps,
                                                           len(predictors.data.lat_around_tg),len(predictors.data.lon_around_tg),len(predictor_vars), 1,'convlstm0',this_dropout, this_lr, lf,l2=this_l2)
                elif model_architecture == 'lstm':
                    model = build_LSTM_stacked(this_n_convlstm, this_n_dense,(np.ones(this_n_convlstm)*this_n_convlstm_units).astype(int), 
                                      (np.ones(this_n_dense)*this_n_dense_units).astype(int),(this_n_steps,
                                                            len(predictors.data.lon_around_tg)**2 * len(predictor_vars)),1,'lstm0',this_dropout, this_lr, lf,l2=this_l2)

                #train model:
                if this_dl_alpha: #if using DenseLoss weights
                    train_history = model.fit(x=x_train,y=y_train,epochs=n_epochs,batch_size=this_batch_size,sample_weight=w_train,validation_data=(x_val,y_val,w_val),
                                              callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience,restore_best_weights=True),GC_Callback()],verbose=2) #with numpy arrays input
                else: #else
                    train_history = model.fit(x=x_train,y=y_train,epochs=n_epochs,batch_size=this_batch_size,validation_data=(x_val,y_val),
                                              callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience,restore_best_weights=True),GC_Callback()],verbose=2) #with numpy arrays input

                #make predictions & back-transform
                yhat_train = model.predict(x_train,verbose=0)*model_input.y_train_sd + model_input.y_train_mean#.flatten()*y_train_sd + y_train_mean
                yhat_val = model.predict(x_val,verbose=0)*model_input.y_train_sd + model_input.y_train_mean#.flatten()*y_train_sd + y_train_mean
                yhat_test = model.predict(x_test,verbose=0)*model_input.y_train_sd + model_input.y_train_mean#.flatten()*y_train_sd + y_train_mean
                
                #store results into xr dataset for current settings and iteration
                ds_train = train_predict_output_to_ds(o_train,yhat_train,model_input.t_train,these_settings,np.array([tg]),model_architecture,lf_name)
                ds_val = train_predict_output_to_ds(o_val,yhat_val,model_input.t_val,these_settings,np.array([tg]),model_architecture,lf_name)
                ds_test = train_predict_output_to_ds(o_test,yhat_test,model_input.t_test,these_settings,np.array([tg]),model_architecture,lf_name)
          
                ds_i = xr.concat((ds_train,ds_val,ds_test),dim='split',coords='different') #concatenate results for each split
                ds_i = ds_i.assign_coords(split = ['train','val','test'])

                ds_i = add_loss_to_output(ds_i,train_history,n_epochs)
                tg_datasets.append(ds_i) #append output of current iteration to list of all outputs
                    
                if store_model:
                    my_path = os.path.join(output_dir,'keras_models',model_architecture)
                    my_fn = model_architecture+'_'+str(temp_freq)+'h_'+tg.replace('.csv','')+'_'+lf_name+'_hp1_i'+str(i)+'_it'
                    
                    model.save(os.path.join(my_path,
                                     my_fn+str(len(fnmatch.filter(os.listdir(my_path),my_fn+'*')))+'.keras'))
                
                del model, model_input, train_history, ds_i #, x_train, x_val, x_test
                tf.keras.backend.clear_session()
                gc.collect()

            #concatenate across runs & compute statistics
            out_ds = xr.concat(tg_datasets,dim='i',coords='different')
            out_ds = add_error_metrics_to_prediction_ds(out_ds,[.95,.98,.99,.995],3) #optional third argument 'max_numT_between_isolated_extremes' to exclude extremes isolated by more than n timesteps from another extreme from evaluation (to avoid including extremes mainly due to semi-diurnal tides, see manuscript for more explanation)

            out_ds = out_ds.assign_coords(lon = ('tg',np.array([predictand.data['lon'].values[0]])))
            out_ds = out_ds.assign_coords(lat = ('tg',np.array([predictand.data['lat'].values[0]])))

            if len(n_steps) == 1: #if n_steps is constant across i, obs doesn't need to have i as a dimension. Saves storage.
                out_ds['o'] = out_ds['o'].isel(i=0,drop=True)
                
            out_ds.attrs['temp_freq'] = temp_freq
            out_ds.attrs['n_cells'] = n_cells
            out_ds.attrs['n_epochs'] = n_epochs
            out_ds.attrs['patience'] = patience
            out_ds.attrs['loss_function'] = lf_name
            out_ds.attrs['split_fractions'] = split_fractions
            out_ds.attrs['stratification'] = strat_metric+'_'+str(strat_start_month)+'_'+str(strat_seed)
            out_ds.attrs['predictor_vars'] = predictor_vars
            
            my_path = os.path.join(output_dir,'performance',model_architecture)
            my_fn = model_architecture+'_'+str(temp_freq)+'h_'+tg.replace('.csv','')+'_'+lf_name+'_hp1_ndeg'+str(predictor_degrees)+'_it'
            
            out_ds.to_netcdf(os.path.join(my_path,my_fn+str(len(fnmatch.filter(os.listdir(my_path),my_fn+'*')))+'.nc'),mode='w')
    return out_ds


if __name__ == "__main__":
    '''
    tgs        = ['stavanger-svg-nor-nhs.csv','wick-wic-gbr-bodc.csv','esbjerg-esb-dnk-dmi.csv',
                  'immingham-imm-gbr-bodc.csv','den_helder-denhdr-nld-rws.csv', 'fishguard-fis-gbr-bodc.csv',  
                  'brest-822a-fra-uhslc.csv', 'vigo-vigo-esp-ieo.csv',  'alicante_i_outer_harbour-alio-esp-da_mm.csv'] #all tide gauges to process
    '''
    # --- allow to set specific function arguments using commandline in "execute_train_and_predit.sh"
    default_tgs = ['den_helder-denhdr-nld-rws.csv'] #set default values
    default_architecture = 'lstm'
    default_alpha = np.array([0,1,3,5]).astype('int')
    default_n_degrees = 5
    
    arguments = sys.argv
    if len(arguments)==5: #if specifying tgs, architecture & alpha values from commandline
        tgs = [arguments[1]] #tg to process
        model_architecture = arguments[2] #architecture to use
        dl_alpha = eval(arguments[3]) #density-based weights tuning parameter
        predictor_degrees = eval(arguments[4])
    else:
        tgs = default_tgs
        model_architecture = default_architecture
        dl_alpha = default_alpha
        predictor_degrees = default_n_degrees
    
    print('Training & predicting for tide gauges: '+str(tgs))
    print('Architecture: '+model_architecture+'; dl_alpha: ' + str(dl_alpha))
    # --- 
    
    #configure standard settings if running main:
    
    #i/o
    predictor_path  = 'gs://leap-persistent/timh37/HighResMIP/surgeNN_predictors/'#'gs://leap-persistent/timh37/era5_predictors/3hourly/'
    predictand_path = '/home/jovyan/test_surge_models/input/GTSM_HighResMIP_HadGEM3-GC31-HM_at_gesla3_tgs_stretched_3hourly_rounded10min_after2.nc' #'/home/jovyan/test_surge_models/input/CoDEC_ERA5_at_gesla3_tgs_eu_hourly_anoms.nc'#'/home/jovyan/test_surge_models/input/t_tide_3h_hourly_deseasoned_predictands'
    output_dir = '/home/jovyan/test_surge_models/results/nns_hadgem3/' #'/home/jovyan/test_surge_models/results/nns/'
    store_model = 0#1 #whether to store the tensorflow models
    temp_freq = 3 # [hours] temporal frequency to use
    
    #training
    predictor_vars = ['msl','u10','v10'] #variables to use
    n_runs = 3 #how many hyperparameter combinations to run
    n_iterations = 10 #how many iterations to run per hyperparameter combination
    n_epochs = 100 #how many training epochs
    patience = 10 #early stopping patience
    loss_function = {'mse':'mse'} # default tensorflow loss function string or string of custom loss function of surgeNN.losses (e.g., 'gevl({gamma})')
    
    #splitting & stratified sampling
    split_fractions = [.6,.2,.2] #train, test, val
    strat_metric = '99pct'
    strat_start_month = 7
    strat_seed = 0

    #hyperparameters:
    dl_alpha = np.array([0,1,3]).astype('int') #defined from command line
    batch_size = np.array([128]).astype('int')
    n_steps = np.array([9]).astype('int')
    n_convlstm = np.array([1]).astype('int')
    n_convlstm_units = np.array([32]).astype('int')
    n_dense = np.array([2]).astype('int')
    n_dense_units = np.array([32]).astype('int')
    dropout = np.array([0.1])
    lrs = np.array([5e-5])
    l1s = np.array([0.02])
    
    predictor_degrees = 3
    
    hyperparam_options = [batch_size, n_steps, n_convlstm, n_convlstm_units,
                    n_dense, n_dense_units, dropout, lrs, l1s, dl_alpha]
    
    out_ds = train_and_predict(model_architecture,loss_function,hyperparam_options, #execute
                      split_fractions,strat_metric,strat_start_month,strat_seed,tgs,n_runs,n_iterations,n_epochs,patience,
                     predictor_path,predictor_vars,predictor_degrees,predictand_path,temp_freq,output_dir,store_model)
# Out:
# 2025-08-06 14:19:07.225647: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-08-06 14:19:07.293574: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Training & predicting for tide gauges: ['den_helder-denhdr-nld-rws.csv']
# Architecture: lstm; dl_alpha: [0 1 3 5]
#   0%|          | 0/1 [00:00<?, ?it/s]/srv/conda/envs/notebook/lib/python3.10/site-packages/xarray/core/dataset.py:255: UserWarning: The specified Dask chunks separate the stored chunks along dimension "time" starting at index 198544. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.10/site-packages/xarray/core/dataset.py:255: UserWarning: The specified Dask chunks separate the stored chunks along dimension "lat_around_tg" starting at index 13. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.10/site-packages/xarray/core/dataset.py:255: UserWarning: The specified Dask chunks separate the stored chunks along dimension "lon_around_tg" starting at index 13. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# 2025-08-06 14:21:33.565728: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/nvidia/lib64
# 2025-08-06 14:21:33.565763: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/100
# 1327/1327 - 10s - loss: 0.5657 - val_loss: 0.4387 - 10s/epoch - 8ms/step
# Epoch 2/100
# 1327/1327 - 8s - loss: 0.4192 - val_loss: 0.3919 - 8s/epoch - 6ms/step
# Epoch 3/100
# 1327/1327 - 8s - loss: 0.3873 - val_loss: 0.3764 - 8s/epoch - 6ms/step
# Epoch 4/100
# 1327/1327 - 8s - loss: 0.3667 - val_loss: 0.3553 - 8s/epoch - 6ms/step
# Epoch 5/100
# 1327/1327 - 8s - loss: 0.3530 - val_loss: 0.3386 - 8s/epoch - 6ms/step
# Epoch 6/100
# 1327/1327 - 8s - loss: 0.3420 - val_loss: 0.3320 - 8s/epoch - 6ms/step
# Epoch 7/100
# 1327/1327 - 8s - loss: 0.3339 - val_loss: 0.3256 - 8s/epoch - 6ms/step
# Epoch 8/100
# 1327/1327 - 8s - loss: 0.3269 - val_loss: 0.3199 - 8s/epoch - 6ms/step
# Epoch 9/100
# 1327/1327 - 8s - loss: 0.3218 - val_loss: 0.3183 - 8s/epoch - 6ms/step
# Epoch 10/100
# 1327/1327 - 8s - loss: 0.3170 - val_loss: 0.3143 - 8s/epoch - 6ms/step
# Epoch 11/100
# 1327/1327 - 8s - loss: 0.3131 - val_loss: 0.3096 - 8s/epoch - 6ms/step
# Epoch 12/100
# 1327/1327 - 8s - loss: 0.3105 - val_loss: 0.3073 - 8s/epoch - 6ms/step
# Epoch 13/100
# 1327/1327 - 9s - loss: 0.3072 - val_loss: 0.3057 - 9s/epoch - 6ms/step
# Epoch 14/100
# 1327/1327 - 9s - loss: 0.3046 - val_loss: 0.3064 - 9s/epoch - 6ms/step
# Epoch 15/100
# 1327/1327 - 8s - loss: 0.3028 - val_loss: 0.3008 - 8s/epoch - 6ms/step
# Epoch 16/100
# 1327/1327 - 8s - loss: 0.3001 - val_loss: 0.3031 - 8s/epoch - 6ms/step
# Epoch 17/100
# 1327/1327 - 8s - loss: 0.2993 - val_loss: 0.2992 - 8s/epoch - 6ms/step
# Epoch 18/100
# 1327/1327 - 8s - loss: 0.2967 - val_loss: 0.2945 - 8s/epoch - 6ms/step
# Epoch 19/100
# 1327/1327 - 8s - loss: 0.2948 - val_loss: 0.3001 - 8s/epoch - 6ms/step
# Epoch 20/100
# 1327/1327 - 8s - loss: 0.2943 - val_loss: 0.2953 - 8s/epoch - 6ms/step
# Epoch 21/100
# 1327/1327 - 8s - loss: 0.2931 - val_loss: 0.2954 - 8s/epoch - 6ms/step
# Epoch 22/100
# 1327/1327 - 8s - loss: 0.2917 - val_loss: 0.2992 - 8s/epoch - 6ms/step
# Epoch 23/100
# 1327/1327 - 8s - loss: 0.2904 - val_loss: 0.2947 - 8s/epoch - 6ms/step
# Epoch 24/100
# 1327/1327 - 8s - loss: 0.2900 - val_loss: 0.2927 - 8s/epoch - 6ms/step
# Epoch 25/100
# 1327/1327 - 8s - loss: 0.2876 - val_loss: 0.2901 - 8s/epoch - 6ms/step
# Epoch 26/100
# 1327/1327 - 9s - loss: 0.2863 - val_loss: 0.2929 - 9s/epoch - 6ms/step
# Epoch 27/100
# 1327/1327 - 8s - loss: 0.2846 - val_loss: 0.2904 - 8s/epoch - 6ms/step
# Epoch 28/100
# 1327/1327 - 8s - loss: 0.2844 - val_loss: 0.2938 - 8s/epoch - 6ms/step
# Epoch 29/100
# 1327/1327 - 8s - loss: 0.2843 - val_loss: 0.2918 - 8s/epoch - 6ms/step
# Epoch 30/100
# 1327/1327 - 8s - loss: 0.2834 - val_loss: 0.2900 - 8s/epoch - 6ms/step
# Epoch 31/100
# 1327/1327 - 8s - loss: 0.2816 - val_loss: 0.2883 - 8s/epoch - 6ms/step
# Epoch 32/100
# 1327/1327 - 8s - loss: 0.2816 - val_loss: 0.2898 - 8s/epoch - 6ms/step
# Epoch 33/100
# 1327/1327 - 8s - loss: 0.2805 - val_loss: 0.2867 - 8s/epoch - 6ms/step
# Epoch 34/100
# 1327/1327 - 8s - loss: 0.2795 - val_loss: 0.2855 - 8s/epoch - 6ms/step
# Epoch 35/100
# 1327/1327 - 8s - loss: 0.2800 - val_loss: 0.2840 - 8s/epoch - 6ms/step
# Epoch 36/100
# 1327/1327 - 8s - loss: 0.2779 - val_loss: 0.2947 - 8s/epoch - 6ms/step
# Epoch 37/100
# 1327/1327 - 8s - loss: 0.2781 - val_loss: 0.2872 - 8s/epoch - 6ms/step
# Epoch 38/100
# 1327/1327 - 8s - loss: 0.2777 - val_loss: 0.2868 - 8s/epoch - 6ms/step
# Epoch 39/100
# 1327/1327 - 8s - loss: 0.2770 - val_loss: 0.2833 - 8s/epoch - 6ms/step
# Epoch 40/100
# 1327/1327 - 8s - loss: 0.2757 - val_loss: 0.3106 - 8s/epoch - 6ms/step
# Epoch 41/100
# 1327/1327 - 8s - loss: 0.2760 - val_loss: 0.2873 - 8s/epoch - 6ms/step
# Epoch 42/100
# 1327/1327 - 8s - loss: 0.2746 - val_loss: 0.2957 - 8s/epoch - 6ms/step
# Epoch 43/100
# 1327/1327 - 8s - loss: 0.2757 - val_loss: 0.2798 - 8s/epoch - 6ms/step
# Epoch 44/100
# 1327/1327 - 8s - loss: 0.2737 - val_loss: 0.2851 - 8s/epoch - 6ms/step
# Epoch 45/100
# 1327/1327 - 8s - loss: 0.2733 - val_loss: 0.2847 - 8s/epoch - 6ms/step
# Epoch 46/100
# 1327/1327 - 8s - loss: 0.2728 - val_loss: 0.2956 - 8s/epoch - 6ms/step
# Epoch 47/100
# 1327/1327 - 8s - loss: 0.2720 - val_loss: 0.2909 - 8s/epoch - 6ms/step
# Epoch 48/100
# 1327/1327 - 8s - loss: 0.2721 - val_loss: 0.2909 - 8s/epoch - 6ms/step
# Epoch 49/100
# 1327/1327 - 8s - loss: 0.2713 - val_loss: 0.2834 - 8s/epoch - 6ms/step
# Epoch 50/100
# 1327/1327 - 8s - loss: 0.2723 - val_loss: 0.2854 - 8s/epoch - 6ms/step
# Epoch 51/100
# 1327/1327 - 8s - loss: 0.2705 - val_loss: 0.2814 - 8s/epoch - 6ms/step
# Epoch 52/100
# 1327/1327 - 8s - loss: 0.2698 - val_loss: 0.2869 - 8s/epoch - 6ms/step
# Epoch 53/100
# 1327/1327 - 8s - loss: 0.2688 - val_loss: 0.2832 - 8s/epoch - 6ms/step
# Epoch 1/100
# 1327/1327 - 16s - loss: 1.0425 - val_loss: 0.7215 - 16s/epoch - 12ms/step
# Epoch 2/100
# 1327/1327 - 8s - loss: 0.6776 - val_loss: 0.6151 - 8s/epoch - 6ms/step
# Epoch 3/100
# 1327/1327 - 8s - loss: 0.6127 - val_loss: 0.5966 - 8s/epoch - 6ms/step
# Epoch 4/100
# 1327/1327 - 8s - loss: 0.5781 - val_loss: 0.5554 - 8s/epoch - 6ms/step
# Epoch 5/100
# 1327/1327 - 8s - loss: 0.5547 - val_loss: 0.5448 - 8s/epoch - 6ms/step
# Epoch 6/100
# 1327/1327 - 8s - loss: 0.5367 - val_loss: 0.5118 - 8s/epoch - 6ms/step
# Epoch 7/100
# 1327/1327 - 9s - loss: 0.5240 - val_loss: 0.5076 - 9s/epoch - 6ms/step
# Epoch 8/100
# 1327/1327 - 8s - loss: 0.5123 - val_loss: 0.4965 - 8s/epoch - 6ms/step
# Epoch 9/100
# 1327/1327 - 8s - loss: 0.5016 - val_loss: 0.4911 - 8s/epoch - 6ms/step
# Epoch 10/100
# 1327/1327 - 8s - loss: 0.4951 - val_loss: 0.4894 - 8s/epoch - 6ms/step
# Epoch 11/100
# 1327/1327 - 9s - loss: 0.4902 - val_loss: 0.4997 - 9s/epoch - 6ms/step
# Epoch 12/100
# 1327/1327 - 8s - loss: 0.4823 - val_loss: 0.4778 - 8s/epoch - 6ms/step
# Epoch 13/100
# 1327/1327 - 9s - loss: 0.4755 - val_loss: 0.4703 - 9s/epoch - 6ms/step
# Epoch 14/100
# 1327/1327 - 9s - loss: 0.4714 - val_loss: 0.4708 - 9s/epoch - 6ms/step
# Epoch 15/100
# 1327/1327 - 9s - loss: 0.4680 - val_loss: 0.4647 - 9s/epoch - 6ms/step
# Epoch 16/100
# 1327/1327 - 8s - loss: 0.4654 - val_loss: 0.4601 - 8s/epoch - 6ms/step
# Epoch 17/100
# 1327/1327 - 8s - loss: 0.4600 - val_loss: 0.4661 - 8s/epoch - 6ms/step
# Epoch 18/100
# 1327/1327 - 8s - loss: 0.4565 - val_loss: 0.4709 - 8s/epoch - 6ms/step
# Epoch 19/100
# 1327/1327 - 8s - loss: 0.4532 - val_loss: 0.4683 - 8s/epoch - 6ms/step
# Epoch 20/100
# 1327/1327 - 8s - loss: 0.4515 - val_loss: 0.4539 - 8s/epoch - 6ms/step
# Epoch 21/100
# 1327/1327 - 9s - loss: 0.4510 - val_loss: 0.4658 - 9s/epoch - 6ms/step
# Epoch 22/100
# 1327/1327 - 9s - loss: 0.4474 - val_loss: 0.4540 - 9s/epoch - 7ms/step
# Epoch 23/100
# 1327/1327 - 9s - loss: 0.4447 - val_loss: 0.4498 - 9s/epoch - 7ms/step
# Epoch 24/100
# 1327/1327 - 9s - loss: 0.4399 - val_loss: 0.4540 - 9s/epoch - 6ms/step
# Epoch 25/100
# 1327/1327 - 9s - loss: 0.4395 - val_loss: 0.4501 - 9s/epoch - 7ms/step
# Epoch 26/100
# 1327/1327 - 8s - loss: 0.4371 - val_loss: 0.4524 - 8s/epoch - 6ms/step
# Epoch 27/100
# 1327/1327 - 8s - loss: 0.4362 - val_loss: 0.4491 - 8s/epoch - 6ms/step
# Epoch 28/100
# 1327/1327 - 8s - loss: 0.4333 - val_loss: 0.4423 - 8s/epoch - 6ms/step
# Epoch 29/100
# 1327/1327 - 8s - loss: 0.4315 - val_loss: 0.4564 - 8s/epoch - 6ms/step
# Epoch 30/100
# 1327/1327 - 8s - loss: 0.4305 - val_loss: 0.4452 - 8s/epoch - 6ms/step
# Epoch 31/100
# 1327/1327 - 8s - loss: 0.4273 - val_loss: 0.4382 - 8s/epoch - 6ms/step
# Epoch 32/100
# 1327/1327 - 8s - loss: 0.4272 - val_loss: 0.4405 - 8s/epoch - 6ms/step
# Epoch 33/100
# 1327/1327 - 9s - loss: 0.4265 - val_loss: 0.4398 - 9s/epoch - 6ms/step
# Epoch 34/100
# 1327/1327 - 9s - loss: 0.4252 - val_loss: 0.4421 - 9s/epoch - 6ms/step
# Epoch 35/100
# 1327/1327 - 9s - loss: 0.4226 - val_loss: 0.4356 - 9s/epoch - 6ms/step
# Epoch 36/100
# 1327/1327 - 8s - loss: 0.4222 - val_loss: 0.4352 - 8s/epoch - 6ms/step
# Epoch 37/100
# 1327/1327 - 8s - loss: 0.4199 - val_loss: 0.4447 - 8s/epoch - 6ms/step
# Epoch 38/100
# 1327/1327 - 8s - loss: 0.4181 - val_loss: 0.4436 - 8s/epoch - 6ms/step
# Epoch 39/100
# 1327/1327 - 8s - loss: 0.4166 - val_loss: 0.4474 - 8s/epoch - 6ms/step
# Epoch 40/100
# 1327/1327 - 8s - loss: 0.4172 - val_loss: 0.4346 - 8s/epoch - 6ms/step
# Epoch 41/100
# 1327/1327 - 8s - loss: 0.4132 - val_loss: 0.4484 - 8s/epoch - 6ms/step
# Epoch 42/100
# 1327/1327 - 8s - loss: 0.4133 - val_loss: 0.4449 - 8s/epoch - 6ms/step
# Epoch 43/100
# 1327/1327 - 8s - loss: 0.4109 - val_loss: 0.4347 - 8s/epoch - 6ms/step
# Epoch 44/100
# 1327/1327 - 8s - loss: 0.4132 - val_loss: 0.4379 - 8s/epoch - 6ms/step
# Epoch 45/100
# 1327/1327 - 9s - loss: 0.4104 - val_loss: 0.4343 - 9s/epoch - 6ms/step
# Epoch 46/100
# 1327/1327 - 8s - loss: 0.4075 - val_loss: 0.4479 - 8s/epoch - 6ms/step
# Epoch 47/100
# 1327/1327 - 8s - loss: 0.4094 - val_loss: 0.4495 - 8s/epoch - 6ms/step
# Epoch 48/100
# 1327/1327 - 8s - loss: 0.4073 - val_loss: 0.4362 - 8s/epoch - 6ms/step
# Epoch 49/100
# 1327/1327 - 9s - loss: 0.4065 - val_loss: 0.4411 - 9s/epoch - 7ms/step
# Epoch 50/100
# 1327/1327 - 9s - loss: 0.4072 - val_loss: 0.4344 - 9s/epoch - 6ms/step
# Epoch 51/100
# 1327/1327 - 8s - loss: 0.4052 - val_loss: 0.4321 - 8s/epoch - 6ms/step
# Epoch 52/100
# 1327/1327 - 8s - loss: 0.4045 - val_loss: 0.4392 - 8s/epoch - 6ms/step
# Epoch 53/100
# 1327/1327 - 8s - loss: 0.4046 - val_loss: 0.4318 - 8s/epoch - 6ms/step
# Epoch 54/100
# 1327/1327 - 8s - loss: 0.4015 - val_loss: 0.4375 - 8s/epoch - 6ms/step
# Epoch 55/100
# 1327/1327 - 8s - loss: 0.4032 - val_loss: 0.4341 - 8s/epoch - 6ms/step
# Epoch 56/100
# 1327/1327 - 8s - loss: 0.4000 - val_loss: 0.4447 - 8s/epoch - 6ms/step
# Epoch 57/100
# 1327/1327 - 8s - loss: 0.3995 - val_loss: 0.4443 - 8s/epoch - 6ms/step
# Epoch 58/100
# 1327/1327 - 8s - loss: 0.3983 - val_loss: 0.4290 - 8s/epoch - 6ms/step
# Epoch 59/100
# 1327/1327 - 8s - loss: 0.3981 - val_loss: 0.4399 - 8s/epoch - 6ms/step
# Epoch 60/100
# 1327/1327 - 8s - loss: 0.3944 - val_loss: 0.4339 - 8s/epoch - 6ms/step
# Epoch 61/100
# 1327/1327 - 8s - loss: 0.3973 - val_loss: 0.4336 - 8s/epoch - 6ms/step
# Epoch 62/100
# 1327/1327 - 8s - loss: 0.3967 - val_loss: 0.4321 - 8s/epoch - 6ms/step
# Epoch 63/100
# 1327/1327 - 8s - loss: 0.3941 - val_loss: 0.4274 - 8s/epoch - 6ms/step
# Epoch 64/100
# 1327/1327 - 9s - loss: 0.3946 - val_loss: 0.4299 - 9s/epoch - 7ms/step
# Epoch 65/100
# 1327/1327 - 9s - loss: 0.3950 - val_loss: 0.4318 - 9s/epoch - 6ms/step
# Epoch 66/100
# 1327/1327 - 8s - loss: 0.3932 - val_loss: 0.4376 - 8s/epoch - 6ms/step
# Epoch 67/100
# 1327/1327 - 8s - loss: 0.3919 - val_loss: 0.4260 - 8s/epoch - 6ms/step
# Epoch 68/100
# 1327/1327 - 8s - loss: 0.3920 - val_loss: 0.4327 - 8s/epoch - 6ms/step
# Epoch 69/100
# 1327/1327 - 8s - loss: 0.3891 - val_loss: 0.4349 - 8s/epoch - 6ms/step
# Epoch 70/100
# 1327/1327 - 8s - loss: 0.3886 - val_loss: 0.4342 - 8s/epoch - 6ms/step
# Epoch 71/100
# 1327/1327 - 8s - loss: 0.3899 - val_loss: 0.4558 - 8s/epoch - 6ms/step
# Epoch 72/100
# 1327/1327 - 8s - loss: 0.3861 - val_loss: 0.4249 - 8s/epoch - 6ms/step
# Epoch 73/100
# 1327/1327 - 8s - loss: 0.3889 - val_loss: 0.4308 - 8s/epoch - 6ms/step
# Epoch 74/100
# 1327/1327 - 8s - loss: 0.3875 - val_loss: 0.4261 - 8s/epoch - 6ms/step
# Epoch 75/100
# 1327/1327 - 8s - loss: 0.3878 - val_loss: 0.4313 - 8s/epoch - 6ms/step
# Epoch 76/100
# 1327/1327 - 8s - loss: 0.3851 - val_loss: 0.4342 - 8s/epoch - 6ms/step
# Epoch 77/100
# 1327/1327 - 8s - loss: 0.3874 - val_loss: 0.4327 - 8s/epoch - 6ms/step
# Epoch 78/100
# 1327/1327 - 8s - loss: 0.3863 - val_loss: 0.4297 - 8s/epoch - 6ms/step
# Epoch 79/100
# 1327/1327 - 8s - loss: 0.3839 - val_loss: 0.4274 - 8s/epoch - 6ms/step
# Epoch 80/100
# 1327/1327 - 9s - loss: 0.3848 - val_loss: 0.4316 - 9s/epoch - 6ms/step
# Epoch 81/100
# 1327/1327 - 8s - loss: 0.3842 - val_loss: 0.4374 - 8s/epoch - 6ms/step
# Epoch 82/100
# 1327/1327 - 10s - loss: 0.3830 - val_loss: 0.4275 - 10s/epoch - 8ms/step
# Epoch 1/100
# 1327/1327 - 18s - loss: 1.7318 - val_loss: 1.1584 - 18s/epoch - 14ms/step
# Epoch 2/100
# 1327/1327 - 10s - loss: 1.0681 - val_loss: 0.8915 - 10s/epoch - 8ms/step
# Epoch 3/100
# 1327/1327 - 10s - loss: 0.9182 - val_loss: 0.8288 - 10s/epoch - 8ms/step
# Epoch 4/100
# 1327/1327 - 10s - loss: 0.8568 - val_loss: 0.7964 - 10s/epoch - 8ms/step
# Epoch 5/100
# 1327/1327 - 10s - loss: 0.8228 - val_loss: 0.7509 - 10s/epoch - 8ms/step
# Epoch 6/100
# 1327/1327 - 10s - loss: 0.8015 - val_loss: 0.7296 - 10s/epoch - 8ms/step
# Epoch 7/100
# 1327/1327 - 10s - loss: 0.7729 - val_loss: 0.7250 - 10s/epoch - 7ms/step
# Epoch 8/100
# 1327/1327 - 10s - loss: 0.7637 - val_loss: 0.7135 - 10s/epoch - 7ms/step
# Epoch 9/100
# 1327/1327 - 10s - loss: 0.7500 - val_loss: 0.7007 - 10s/epoch - 7ms/step
# Epoch 10/100
# 1327/1327 - 10s - loss: 0.7298 - val_loss: 0.7157 - 10s/epoch - 7ms/step
# Epoch 11/100
# 1327/1327 - 10s - loss: 0.7189 - val_loss: 0.6850 - 10s/epoch - 7ms/step
# Epoch 12/100
# 1327/1327 - 10s - loss: 0.7063 - val_loss: 0.6772 - 10s/epoch - 7ms/step
# Epoch 13/100
# 1327/1327 - 9s - loss: 0.6944 - val_loss: 0.6885 - 9s/epoch - 7ms/step
# Epoch 14/100
# 1327/1327 - 9s - loss: 0.6827 - val_loss: 0.6913 - 9s/epoch - 7ms/step
# Epoch 15/100
# 1327/1327 - 9s - loss: 0.6717 - val_loss: 0.6696 - 9s/epoch - 7ms/step
# Epoch 16/100
# 1327/1327 - 9s - loss: 0.6670 - val_loss: 0.6587 - 9s/epoch - 7ms/step
# Epoch 17/100
# 1327/1327 - 9s - loss: 0.6563 - val_loss: 0.6632 - 9s/epoch - 7ms/step
# Epoch 18/100
# 1327/1327 - 9s - loss: 0.6544 - val_loss: 0.6514 - 9s/epoch - 7ms/step
# Epoch 19/100
# 1327/1327 - 9s - loss: 0.6436 - val_loss: 0.6662 - 9s/epoch - 7ms/step
# Epoch 20/100
# 1327/1327 - 8s - loss: 0.6378 - val_loss: 0.6497 - 8s/epoch - 6ms/step
# Epoch 21/100
# 1327/1327 - 8s - loss: 0.6309 - val_loss: 0.6516 - 8s/epoch - 6ms/step
# Epoch 22/100
# 1327/1327 - 8s - loss: 0.6264 - val_loss: 0.6586 - 8s/epoch - 6ms/step
# Epoch 23/100
# 1327/1327 - 8s - loss: 0.6216 - val_loss: 0.6400 - 8s/epoch - 6ms/step
# Epoch 24/100
# 1327/1327 - 8s - loss: 0.6156 - val_loss: 0.6460 - 8s/epoch - 6ms/step
# Epoch 25/100
# 1327/1327 - 8s - loss: 0.6130 - val_loss: 0.6494 - 8s/epoch - 6ms/step
# Epoch 26/100
# 1327/1327 - 8s - loss: 0.6031 - val_loss: 0.6411 - 8s/epoch - 6ms/step
# Epoch 27/100
# 1327/1327 - 8s - loss: 0.5966 - val_loss: 0.6714 - 8s/epoch - 6ms/step
# Epoch 28/100
# 1327/1327 - 8s - loss: 0.5909 - val_loss: 0.6065 - 8s/epoch - 6ms/step
# Epoch 29/100
# 1327/1327 - 8s - loss: 0.5853 - val_loss: 0.6714 - 8s/epoch - 6ms/step
# Epoch 30/100
# 1327/1327 - 8s - loss: 0.5885 - val_loss: 0.6260 - 8s/epoch - 6ms/step
# Epoch 31/100
# 1327/1327 - 8s - loss: 0.5845 - val_loss: 0.6225 - 8s/epoch - 6ms/step
# Epoch 32/100
# 1327/1327 - 8s - loss: 0.5793 - val_loss: 0.6278 - 8s/epoch - 6ms/step
# Epoch 33/100
# 1327/1327 - 8s - loss: 0.5729 - val_loss: 0.6259 - 8s/epoch - 6ms/step
# Epoch 34/100
# 1327/1327 - 8s - loss: 0.5725 - val_loss: 0.6200 - 8s/epoch - 6ms/step
# Epoch 35/100
# 1327/1327 - 8s - loss: 0.5622 - val_loss: 0.6790 - 8s/epoch - 6ms/step
# Epoch 36/100
# 1327/1327 - 8s - loss: 0.5642 - val_loss: 0.6379 - 8s/epoch - 6ms/step
# Epoch 37/100
# 1327/1327 - 8s - loss: 0.5560 - val_loss: 0.6156 - 8s/epoch - 6ms/step
# Epoch 38/100
# 1327/1327 - 8s - loss: 0.5516 - val_loss: 0.6255 - 8s/epoch - 6ms/step
# Epoch 1/100
# 1327/1327 - 10s - loss: 0.5714 - val_loss: 0.4277 - 10s/epoch - 8ms/step
# Epoch 2/100
# 1327/1327 - 8s - loss: 0.4072 - val_loss: 0.3870 - 8s/epoch - 6ms/step
# Epoch 3/100
# 1327/1327 - 9s - loss: 0.3757 - val_loss: 0.3721 - 9s/epoch - 7ms/step
# Epoch 4/100
# 1327/1327 - 8s - loss: 0.3575 - val_loss: 0.3475 - 8s/epoch - 6ms/step
# Epoch 5/100
# 1327/1327 - 8s - loss: 0.3454 - val_loss: 0.3369 - 8s/epoch - 6ms/step
# Epoch 6/100
# 1327/1327 - 8s - loss: 0.3373 - val_loss: 0.3272 - 8s/epoch - 6ms/step
# Epoch 7/100
# 1327/1327 - 8s - loss: 0.3296 - val_loss: 0.3219 - 8s/epoch - 6ms/step
# Epoch 8/100
# 1327/1327 - 8s - loss: 0.3230 - val_loss: 0.3284 - 8s/epoch - 6ms/step
# Epoch 9/100
# 1327/1327 - 8s - loss: 0.3186 - val_loss: 0.3142 - 8s/epoch - 6ms/step
# Epoch 10/100
# 1327/1327 - 8s - loss: 0.3127 - val_loss: 0.3183 - 8s/epoch - 6ms/step
# Epoch 11/100
# 1327/1327 - 8s - loss: 0.3092 - val_loss: 0.3084 - 8s/epoch - 6ms/step
# Epoch 12/100
# 1327/1327 - 8s - loss: 0.3069 - val_loss: 0.3018 - 8s/epoch - 6ms/step
# Epoch 13/100
# Epoch 1/100
# 1327/1327 - 16s - loss: 1.0025 - val_loss: 0.6841 - 16s/epoch - 12ms/step
# Epoch 2/100
# 1327/1327 - 8s - loss: 0.6600 - val_loss: 0.6044 - 8s/epoch - 6ms/step
# Epoch 3/100
# 1327/1327 - 8s - loss: 0.5987 - val_loss: 0.5705 - 8s/epoch - 6ms/step
# Epoch 4/100
# 1327/1327 - 8s - loss: 0.5693 - val_loss: 0.5481 - 8s/epoch - 6ms/step
# Epoch 5/100
# 1327/1327 - 9s - loss: 0.5520 - val_loss: 0.5379 - 9s/epoch - 7ms/step
# Epoch 6/100
# 1327/1327 - 8s - loss: 0.5383 - val_loss: 0.5344 - 8s/epoch - 6ms/step
# Epoch 7/100
# 1327/1327 - 9s - loss: 0.5213 - val_loss: 0.5266 - 9s/epoch - 7ms/step
# Epoch 8/100
# 1327/1327 - 9s - loss: 0.5130 - val_loss: 0.5013 - 9s/epoch - 7ms/step
# Epoch 9/100
# 1327/1327 - 9s - loss: 0.5021 - val_loss: 0.4948 - 9s/epoch - 7ms/step
# Epoch 10/100
# 1327/1327 - 9s - loss: 0.4970 - val_loss: 0.4923 - 9s/epoch - 7ms/step
# Epoch 11/100
# 1327/1327 - 9s - loss: 0.4897 - val_loss: 0.4878 - 9s/epoch - 7ms/step
# Epoch 12/100
# 1327/1327 - 9s - loss: 0.4813 - val_loss: 0.4767 - 9s/epoch - 7ms/step
# Epoch 13/100
# 1327/1327 - 9s - loss: 0.4763 - val_loss: 0.4681 - 9s/epoch - 7ms/step
# Epoch 14/100
# 1327/1327 - 9s - loss: 0.4684 - val_loss: 0.4898 - 9s/epoch - 7ms/step
# Epoch 15/100
# 1327/1327 - 9s - loss: 0.4677 - val_loss: 0.4700 - 9s/epoch - 7ms/step
# Epoch 16/100
# 1327/1327 - 9s - loss: 0.4633 - val_loss: 0.4571 - 9s/epoch - 7ms/step
# Epoch 17/100
# 1327/1327 - 9s - loss: 0.4579 - val_loss: 0.4633 - 9s/epoch - 7ms/step
# Epoch 18/100
# 1327/1327 - 9s - loss: 0.4545 - val_loss: 0.4651 - 9s/epoch - 7ms/step
# Epoch 19/100
# 1327/1327 - 9s - loss: 0.4517 - val_loss: 0.4711 - 9s/epoch - 7ms/step
# Epoch 20/100
# 1327/1327 - 9s - loss: 0.4494 - val_loss: 0.4648 - 9s/epoch - 7ms/step
# Epoch 21/100
# 1327/1327 - 9s - loss: 0.4470 - val_loss: 0.4693 - 9s/epoch - 7ms/step
# Epoch 22/100
# 1327/1327 - 9s - loss: 0.4443 - val_loss: 0.4509 - 9s/epoch - 7ms/step
# Epoch 23/100
# 1327/1327 - 9s - loss: 0.4435 - val_loss: 0.4424 - 9s/epoch - 7ms/step
# Epoch 24/100
# 1327/1327 - 9s - loss: 0.4393 - val_loss: 0.4505 - 9s/epoch - 7ms/step
# Epoch 25/100
# 1327/1327 - 9s - loss: 0.4362 - val_loss: 0.4445 - 9s/epoch - 7ms/step
# Epoch 26/100
# 1327/1327 - 9s - loss: 0.4355 - val_loss: 0.4468 - 9s/epoch - 7ms/step
# Epoch 27/100
# 1327/1327 - 9s - loss: 0.4343 - val_loss: 0.4534 - 9s/epoch - 7ms/step
# Epoch 28/100
# 1327/1327 - 9s - loss: 0.4304 - val_loss: 0.4607 - 9s/epoch - 7ms/step
# Epoch 29/100
# 1327/1327 - 9s - loss: 0.4300 - val_loss: 0.4774 - 9s/epoch - 7ms/step
# Epoch 30/100
# 1327/1327 - 9s - loss: 0.4279 - val_loss: 0.4701 - 9s/epoch - 7ms/step
# Epoch 31/100
# 1327/1327 - 9s - loss: 0.4280 - val_loss: 0.4395 - 9s/epoch - 7ms/step
# Epoch 32/100
# 1327/1327 - 9s - loss: 0.4252 - val_loss: 0.4536 - 9s/epoch - 7ms/step
# Epoch 33/100
# 1327/1327 - 9s - loss: 0.4248 - val_loss: 0.4500 - 9s/epoch - 6ms/step
# Epoch 34/100
# 1327/1327 - 8s - loss: 0.4223 - val_loss: 0.4341 - 8s/epoch - 6ms/step
# Epoch 35/100
# 1327/1327 - 9s - loss: 0.4183 - val_loss: 0.4499 - 9s/epoch - 6ms/step
# Epoch 36/100
# 1327/1327 - 9s - loss: 0.4192 - val_loss: 0.4376 - 9s/epoch - 6ms/step
# Epoch 37/100
# 1327/1327 - 9s - loss: 0.4192 - val_loss: 0.4339 - 9s/epoch - 7ms/step
# Epoch 38/100
# 1327/1327 - 9s - loss: 0.4153 - val_loss: 0.4408 - 9s/epoch - 7ms/step
# Epoch 39/100
# 1327/1327 - 9s - loss: 0.4149 - val_loss: 0.4376 - 9s/epoch - 7ms/step
# Epoch 40/100
# 1327/1327 - 9s - loss: 0.4125 - val_loss: 0.4290 - 9s/epoch - 7ms/step
# Epoch 41/100
# 1327/1327 - 9s - loss: 0.4127 - val_loss: 0.4614 - 9s/epoch - 7ms/step
# Epoch 42/100
# 1327/1327 - 9s - loss: 0.4134 - val_loss: 0.4397 - 9s/epoch - 7ms/step
# Epoch 43/100
# 1327/1327 - 9s - loss: 0.4117 - val_loss: 0.4508 - 9s/epoch - 7ms/step
# Epoch 44/100
# 1327/1327 - 9s - loss: 0.4110 - val_loss: 0.4336 - 9s/epoch - 7ms/step
# Epoch 45/100
# 1327/1327 - 9s - loss: 0.4084 - val_loss: 0.4338 - 9s/epoch - 7ms/step
# Epoch 46/100
# 1327/1327 - 9s - loss: 0.4076 - val_loss: 0.4337 - 9s/epoch - 7ms/step
# Epoch 47/100
# 1327/1327 - 9s - loss: 0.4088 - val_loss: 0.4272 - 9s/epoch - 7ms/step
# Epoch 48/100
# 1327/1327 - 9s - loss: 0.4054 - val_loss: 0.4365 - 9s/epoch - 7ms/step
# Epoch 49/100
# 1327/1327 - 9s - loss: 0.4055 - val_loss: 0.4473 - 9s/epoch - 7ms/step
# Epoch 50/100
# 1327/1327 - 9s - loss: 0.4029 - val_loss: 0.4296 - 9s/epoch - 7ms/step
# Epoch 51/100
# 1327/1327 - 9s - loss: 0.4040 - val_loss: 0.4281 - 9s/epoch - 7ms/step
# Epoch 52/100
# 1327/1327 - 9s - loss: 0.4043 - val_loss: 0.4431 - 9s/epoch - 7ms/step
# Epoch 53/100
# 1327/1327 - 9s - loss: 0.4027 - val_loss: 0.4270 - 9s/epoch - 7ms/step
# Epoch 54/100
# 1327/1327 - 9s - loss: 0.4003 - val_loss: 0.4264 - 9s/epoch - 7ms/step
# Epoch 55/100
# 1327/1327 - 9s - loss: 0.4011 - val_loss: 0.4340 - 9s/epoch - 7ms/step
# Epoch 56/100
# 1327/1327 - 9s - loss: 0.4006 - val_loss: 0.4335 - 9s/epoch - 7ms/step
# Epoch 57/100
# 1327/1327 - 9s - loss: 0.3975 - val_loss: 0.4403 - 9s/epoch - 7ms/step
# Epoch 58/100
# 1327/1327 - 9s - loss: 0.3999 - val_loss: 0.4334 - 9s/epoch - 7ms/step
# Epoch 59/100
# 1327/1327 - 9s - loss: 0.3972 - val_loss: 0.4319 - 9s/epoch - 7ms/step
# Epoch 60/100
# 1327/1327 - 9s - loss: 0.3953 - val_loss: 0.4285 - 9s/epoch - 7ms/step
# Epoch 61/100
# 1327/1327 - 9s - loss: 0.3971 - val_loss: 0.4314 - 9s/epoch - 7ms/step
# Epoch 62/100
# 1327/1327 - 9s - loss: 0.3957 - val_loss: 0.4305 - 9s/epoch - 7ms/step
# Epoch 63/100
# 1327/1327 - 9s - loss: 0.3954 - val_loss: 0.4239 - 9s/epoch - 7ms/step
# Epoch 64/100
# 1327/1327 - 9s - loss: 0.3939 - val_loss: 0.4332 - 9s/epoch - 7ms/step
# Epoch 65/100
# 1327/1327 - 9s - loss: 0.3935 - val_loss: 0.4493 - 9s/epoch - 7ms/step
# Epoch 66/100
# 1327/1327 - 9s - loss: 0.3927 - val_loss: 0.4429 - 9s/epoch - 7ms/step
# Epoch 67/100
# 1327/1327 - 9s - loss: 0.3916 - val_loss: 0.4314 - 9s/epoch - 7ms/step
# Epoch 68/100
# 1327/1327 - 9s - loss: 0.3926 - val_loss: 0.4361 - 9s/epoch - 7ms/step
# Epoch 69/100
# 1327/1327 - 9s - loss: 0.3903 - val_loss: 0.4322 - 9s/epoch - 7ms/step
# Epoch 70/100
# 1327/1327 - 9s - loss: 0.3900 - val_loss: 0.4272 - 9s/epoch - 7ms/step
# Epoch 71/100
# 1327/1327 - 9s - loss: 0.3883 - val_loss: 0.4235 - 9s/epoch - 7ms/step
# Epoch 72/100
# 1327/1327 - 9s - loss: 0.3877 - val_loss: 0.4295 - 9s/epoch - 7ms/step
# Epoch 73/100
# 1327/1327 - 9s - loss: 0.3881 - val_loss: 0.4514 - 9s/epoch - 7ms/step
# Epoch 74/100
# 1327/1327 - 9s - loss: 0.3874 - val_loss: 0.4330 - 9s/epoch - 7ms/step
# Epoch 75/100
# 1327/1327 - 9s - loss: 0.3900 - val_loss: 0.4438 - 9s/epoch - 7ms/step
# Epoch 76/100
# 1327/1327 - 9s - loss: 0.3851 - val_loss: 0.4374 - 9s/epoch - 7ms/step
# Epoch 77/100
# 1327/1327 - 9s - loss: 0.3842 - val_loss: 0.4489 - 9s/epoch - 7ms/step
# Epoch 78/100
# 1327/1327 - 9s - loss: 0.3856 - val_loss: 0.4304 - 9s/epoch - 7ms/step
# Epoch 79/100
# 1327/1327 - 9s - loss: 0.3823 - val_loss: 0.4322 - 9s/epoch - 7ms/step
# Epoch 80/100
# 1327/1327 - 9s - loss: 0.3844 - val_loss: 0.4363 - 9s/epoch - 7ms/step
# Epoch 81/100
# 1327/1327 - 9s - loss: 0.3830 - val_loss: 0.4310 - 9s/epoch - 7ms/step
# Epoch 1/100
# 1327/1327 - 17s - loss: 2.2250 - val_loss: 1.3048 - 17s/epoch - 13ms/step
# Epoch 2/100
# 1327/1327 - 9s - loss: 1.1573 - val_loss: 0.9293 - 9s/epoch - 7ms/step
# Epoch 3/100
# 1327/1327 - 9s - loss: 0.9621 - val_loss: 0.8260 - 9s/epoch - 7ms/step
# Epoch 4/100
# 1327/1327 - 9s - loss: 0.8696 - val_loss: 0.7730 - 9s/epoch - 7ms/step
# Epoch 5/100
# 1327/1327 - 9s - loss: 0.8197 - val_loss: 0.7510 - 9s/epoch - 7ms/step
# Epoch 6/100
# 1327/1327 - 9s - loss: 0.7873 - val_loss: 0.7405 - 9s/epoch - 7ms/step
# Epoch 7/100
# 1327/1327 - 9s - loss: 0.7658 - val_loss: 0.7412 - 9s/epoch - 7ms/step
# Epoch 8/100
# 1327/1327 - 9s - loss: 0.7468 - val_loss: 0.6973 - 9s/epoch - 7ms/step
# Epoch 9/100
# 1327/1327 - 9s - loss: 0.7290 - val_loss: 0.6866 - 9s/epoch - 7ms/step
# Epoch 10/100
# 1327/1327 - 9s - loss: 0.7209 - val_loss: 0.6741 - 9s/epoch - 7ms/step
# Epoch 11/100
# 1327/1327 - 9s - loss: 0.7029 - val_loss: 0.7179 - 9s/epoch - 7ms/step
# Epoch 12/100
# 1327/1327 - 9s - loss: 0.6940 - val_loss: 0.6848 - 9s/epoch - 7ms/step
# Epoch 13/100
# 1327/1327 - 9s - loss: 0.6827 - val_loss: 0.6527 - 9s/epoch - 7ms/step
# Epoch 14/100
# 1327/1327 - 9s - loss: 0.6740 - val_loss: 0.6623 - 9s/epoch - 7ms/step
# Epoch 15/100
# 1327/1327 - 9s - loss: 0.6640 - val_loss: 0.6627 - 9s/epoch - 7ms/step
# Epoch 16/100
# 1327/1327 - 9s - loss: 0.6564 - val_loss: 0.6600 - 9s/epoch - 7ms/step
# Epoch 17/100
# 1327/1327 - 9s - loss: 0.6451 - val_loss: 0.6675 - 9s/epoch - 7ms/step
# Epoch 18/100
# 1327/1327 - 9s - loss: 0.6396 - val_loss: 0.6842 - 9s/epoch - 7ms/step
# Epoch 19/100
# 1327/1327 - 9s - loss: 0.6332 - val_loss: 0.6707 - 9s/epoch - 7ms/step
# Epoch 20/100
# 1327/1327 - 9s - loss: 0.6288 - val_loss: 0.6406 - 9s/epoch - 7ms/step
# Epoch 21/100
# 1327/1327 - 9s - loss: 0.6258 - val_loss: 0.6352 - 9s/epoch - 7ms/step
# Epoch 22/100
# 1327/1327 - 9s - loss: 0.6148 - val_loss: 0.6239 - 9s/epoch - 7ms/step
# Epoch 23/100
# 1327/1327 - 9s - loss: 0.6114 - val_loss: 0.6321 - 9s/epoch - 7ms/step
# Epoch 24/100
# 1327/1327 - 9s - loss: 0.6106 - val_loss: 0.6301 - 9s/epoch - 7ms/step
# Epoch 25/100
# 1327/1327 - 9s - loss: 0.6043 - val_loss: 0.6433 - 9s/epoch - 7ms/step
# Epoch 26/100
# 1327/1327 - 9s - loss: 0.6053 - val_loss: 0.6560 - 9s/epoch - 7ms/step
# Epoch 27/100
# 1327/1327 - 9s - loss: 0.5949 - val_loss: 0.6282 - 9s/epoch - 7ms/step
# Epoch 28/100
# 1327/1327 - 9s - loss: 0.5889 - val_loss: 0.6488 - 9s/epoch - 7ms/step
# Epoch 29/100
# 1327/1327 - 9s - loss: 0.5871 - val_loss: 0.6198 - 9s/epoch - 7ms/step
# Epoch 30/100
# 1327/1327 - 9s - loss: 0.5859 - val_loss: 0.6132 - 9s/epoch - 7ms/step
# Epoch 31/100
# 1327/1327 - 9s - loss: 0.5831 - val_loss: 0.6085 - 9s/epoch - 7ms/step
# Epoch 32/100
# 1327/1327 - 9s - loss: 0.5749 - val_loss: 0.6746 - 9s/epoch - 7ms/step
# Epoch 33/100
# 1327/1327 - 9s - loss: 0.5689 - val_loss: 0.6404 - 9s/epoch - 7ms/step
# Epoch 34/100
# 1327/1327 - 9s - loss: 0.5695 - val_loss: 0.5967 - 9s/epoch - 7ms/step
# Epoch 35/100
# 1327/1327 - 9s - loss: 0.5684 - val_loss: 0.6085 - 9s/epoch - 7ms/step
# Epoch 36/100
# 1327/1327 - 9s - loss: 0.5655 - val_loss: 0.6242 - 9s/epoch - 7ms/step
# Epoch 37/100
# Epoch 1/100
# 1327/1327 - 11s - loss: 0.5938 - val_loss: 0.4466 - 11s/epoch - 8ms/step
# Epoch 2/100
# 1327/1327 - 9s - loss: 0.4206 - val_loss: 0.3916 - 9s/epoch - 7ms/step
# Epoch 3/100
# 1327/1327 - 9s - loss: 0.3844 - val_loss: 0.3672 - 9s/epoch - 7ms/step
# Epoch 4/100
# 1327/1327 - 9s - loss: 0.3639 - val_loss: 0.3570 - 9s/epoch - 7ms/step
# Epoch 5/100
# 1327/1327 - 9s - loss: 0.3512 - val_loss: 0.3450 - 9s/epoch - 7ms/step
# Epoch 6/100
# 1327/1327 - 9s - loss: 0.3405 - val_loss: 0.3317 - 9s/epoch - 7ms/step
# Epoch 7/100
# 1327/1327 - 9s - loss: 0.3321 - val_loss: 0.3293 - 9s/epoch - 7ms/step
# Epoch 8/100
# 1327/1327 - 9s - loss: 0.3249 - val_loss: 0.3268 - 9s/epoch - 7ms/step
# Epoch 9/100
# 1327/1327 - 9s - loss: 0.3207 - val_loss: 0.3173 - 9s/epoch - 7ms/step
# Epoch 10/100
# 1327/1327 - 9s - loss: 0.3159 - val_loss: 0.3109 - 9s/epoch - 7ms/step
# Epoch 11/100
# 1327/1327 - 9s - loss: 0.3121 - val_loss: 0.3104 - 9s/epoch - 7ms/step
# Epoch 12/100
# 1327/1327 - 9s - loss: 0.3082 - val_loss: 0.3092 - 9s/epoch - 7ms/step
# Epoch 13/100
# 1327/1327 - 9s - loss: 0.3066 - val_loss: 0.3067 - 9s/epoch - 7ms/step
# Epoch 14/100
# 1327/1327 - 9s - loss: 0.3038 - val_loss: 0.3077 - 9s/epoch - 7ms/step
# Epoch 15/100
# 1327/1327 - 9s - loss: 0.3015 - val_loss: 0.3073 - 9s/epoch - 7ms/step
# Epoch 16/100
# 1327/1327 - 9s - loss: 0.2987 - val_loss: 0.3030 - 9s/epoch - 7ms/step
# Epoch 17/100
# 1327/1327 - 9s - loss: 0.2973 - val_loss: 0.3100 - 9s/epoch - 7ms/step
# Epoch 18/100
# 1327/1327 - 9s - loss: 0.2952 - val_loss: 0.3015 - 9s/epoch - 7ms/step
# Epoch 19/100
# 1327/1327 - 9s - loss: 0.2937 - val_loss: 0.2959 - 9s/epoch - 7ms/step
# Epoch 20/100
# 1327/1327 - 9s - loss: 0.2924 - val_loss: 0.2993 - 9s/epoch - 7ms/step
# Epoch 21/100
# 1327/1327 - 9s - loss: 0.2904 - val_loss: 0.2949 - 9s/epoch - 7ms/step
# Epoch 22/100
# 1327/1327 - 9s - loss: 0.2902 - val_loss: 0.3029 - 9s/epoch - 7ms/step
# Epoch 23/100
# 1327/1327 - 9s - loss: 0.2890 - val_loss: 0.2971 - 9s/epoch - 7ms/step
# Epoch 24/100
# 1327/1327 - 9s - loss: 0.2890 - val_loss: 0.2937 - 9s/epoch - 7ms/step
# Epoch 25/100
# 1327/1327 - 9s - loss: 0.2856 - val_loss: 0.2925 - 9s/epoch - 7ms/step
# Epoch 26/100
# 1327/1327 - 9s - loss: 0.2856 - val_loss: 0.2988 - 9s/epoch - 7ms/step
# Epoch 27/100
# 1327/1327 - 9s - loss: 0.2852 - val_loss: 0.3058 - 9s/epoch - 7ms/step
# Epoch 28/100
# 1327/1327 - 9s - loss: 0.2837 - val_loss: 0.2986 - 9s/epoch - 7ms/step
# Epoch 29/100
# 1327/1327 - 9s - loss: 0.2824 - val_loss: 0.3038 - 9s/epoch - 7ms/step
# Epoch 30/100
# 1327/1327 - 9s - loss: 0.2819 - val_loss: 0.2909 - 9s/epoch - 7ms/step
# Epoch 31/100
# 1327/1327 - 9s - loss: 0.2813 - val_loss: 0.2868 - 9s/epoch - 7ms/step
# Epoch 32/100
# 1327/1327 - 9s - loss: 0.2808 - val_loss: 0.2958 - 9s/epoch - 7ms/step
# Epoch 33/100
# 1327/1327 - 9s - loss: 0.2811 - val_loss: 0.2902 - 9s/epoch - 7ms/step
# Epoch 34/100
# 1327/1327 - 9s - loss: 0.2790 - val_loss: 0.2896 - 9s/epoch - 7ms/step
# Epoch 35/100
# 1327/1327 - 9s - loss: 0.2783 - val_loss: 0.2872 - 9s/epoch - 7ms/step
# Epoch 36/100
# 1327/1327 - 9s - loss: 0.2779 - val_loss: 0.2872 - 9s/epoch - 7ms/step
# Epoch 37/100
# 1327/1327 - 9s - loss: 0.2763 - val_loss: 0.2889 - 9s/epoch - 6ms/step
# Epoch 38/100
# 1327/1327 - 9s - loss: 0.2761 - val_loss: 0.2891 - 9s/epoch - 6ms/step
# Epoch 39/100
# 1327/1327 - 9s - loss: 0.2754 - val_loss: 0.2899 - 9s/epoch - 6ms/step
# Epoch 40/100
# 1327/1327 - 8s - loss: 0.2752 - val_loss: 0.2866 - 8s/epoch - 6ms/step
# Epoch 41/100
# 1327/1327 - 8s - loss: 0.2752 - val_loss: 0.2874 - 8s/epoch - 6ms/step
# Epoch 42/100
# 1327/1327 - 8s - loss: 0.2740 - val_loss: 0.2863 - 8s/epoch - 6ms/step
# Epoch 43/100
# 1327/1327 - 8s - loss: 0.2726 - val_loss: 0.2858 - 8s/epoch - 6ms/step
# Epoch 44/100
# 1327/1327 - 8s - loss: 0.2726 - val_loss: 0.2958 - 8s/epoch - 6ms/step
# Epoch 45/100
# 1327/1327 - 8s - loss: 0.2722 - val_loss: 0.2854 - 8s/epoch - 6ms/step
# Epoch 46/100
# 1327/1327 - 8s - loss: 0.2724 - val_loss: 0.2875 - 8s/epoch - 6ms/step
# Epoch 47/100
# 1327/1327 - 8s - loss: 0.2720 - val_loss: 0.2913 - 8s/epoch - 6ms/step
# Epoch 48/100
# 1327/1327 - 9s - loss: 0.2702 - val_loss: 0.2872 - 9s/epoch - 6ms/step
# Epoch 49/100
# 1327/1327 - 8s - loss: 0.2711 - val_loss: 0.2869 - 8s/epoch - 6ms/step
# Epoch 50/100
# 1327/1327 - 9s - loss: 0.2697 - val_loss: 0.2871 - 9s/epoch - 6ms/step
# Epoch 51/100
# 1327/1327 - 8s - loss: 0.2694 - val_loss: 0.2896 - 8s/epoch - 6ms/step
# Epoch 52/100
# 1327/1327 - 8s - loss: 0.2698 - val_loss: 0.2917 - 8s/epoch - 6ms/step
# Epoch 53/100
# 1327/1327 - 8s - loss: 0.2689 - val_loss: 0.2855 - 8s/epoch - 6ms/step
# Epoch 54/100
# 1327/1327 - 9s - loss: 0.2678 - val_loss: 0.2863 - 9s/epoch - 6ms/step
# Epoch 55/100
# 1327/1327 - 8s - loss: 0.2671 - val_loss: 0.2868 - 8s/epoch - 6ms/step
# Epoch 1/100
# 1327/1327 - 16s - loss: 0.9808 - val_loss: 0.6941 - 16s/epoch - 12ms/step
# Epoch 2/100
# 1327/1327 - 8s - loss: 0.6599 - val_loss: 0.6024 - 8s/epoch - 6ms/step
# Epoch 3/100
# 1327/1327 - 8s - loss: 0.6052 - val_loss: 0.5696 - 8s/epoch - 6ms/step
# Epoch 4/100
# 1327/1327 - 9s - loss: 0.5716 - val_loss: 0.5437 - 9s/epoch - 6ms/step
# Epoch 5/100
# 1327/1327 - 8s - loss: 0.5497 - val_loss: 0.5223 - 8s/epoch - 6ms/step
# Epoch 6/100
# 1327/1327 - 8s - loss: 0.5345 - val_loss: 0.5184 - 8s/epoch - 6ms/step
# Epoch 7/100
# 1327/1327 - 8s - loss: 0.5227 - val_loss: 0.5055 - 8s/epoch - 6ms/step
# Epoch 8/100
# 1327/1327 - 8s - loss: 0.5120 - val_loss: 0.5162 - 8s/epoch - 6ms/step
# Epoch 9/100
# 1327/1327 - 8s - loss: 0.5027 - val_loss: 0.4978 - 8s/epoch - 6ms/step
# Epoch 10/100
# 1327/1327 - 8s - loss: 0.4932 - val_loss: 0.4831 - 8s/epoch - 6ms/step
# Epoch 11/100
# 1327/1327 - 8s - loss: 0.4871 - val_loss: 0.4818 - 8s/epoch - 6ms/step
# Epoch 12/100
# 1327/1327 - 8s - loss: 0.4834 - val_loss: 0.4828 - 8s/epoch - 6ms/step
# Epoch 13/100
# 1327/1327 - 8s - loss: 0.4760 - val_loss: 0.4869 - 8s/epoch - 6ms/step
# Epoch 14/100
# 1327/1327 - 8s - loss: 0.4710 - val_loss: 0.4910 - 8s/epoch - 6ms/step
# Epoch 15/100
# 1327/1327 - 8s - loss: 0.4675 - val_loss: 0.4717 - 8s/epoch - 6ms/step
# Epoch 16/100
# 1327/1327 - 9s - loss: 0.4633 - val_loss: 0.4703 - 9s/epoch - 6ms/step
# Epoch 17/100
# 1327/1327 - 8s - loss: 0.4593 - val_loss: 0.4597 - 8s/epoch - 6ms/step
# Epoch 18/100
# 1327/1327 - 9s - loss: 0.4556 - val_loss: 0.4705 - 9s/epoch - 6ms/step
# Epoch 19/100
# 1327/1327 - 9s - loss: 0.4531 - val_loss: 0.4660 - 9s/epoch - 6ms/step
# Epoch 20/100
# 1327/1327 - 9s - loss: 0.4481 - val_loss: 0.4586 - 9s/epoch - 6ms/step
# Epoch 21/100
# 1327/1327 - 8s - loss: 0.4464 - val_loss: 0.4586 - 8s/epoch - 6ms/step
# Epoch 22/100
# 1327/1327 - 8s - loss: 0.4474 - val_loss: 0.4560 - 8s/epoch - 6ms/step
# Epoch 23/100
# 1327/1327 - 8s - loss: 0.4415 - val_loss: 0.4610 - 8s/epoch - 6ms/step
# Epoch 24/100
# 1327/1327 - 8s - loss: 0.4382 - val_loss: 0.4649 - 8s/epoch - 6ms/step
# Epoch 25/100
# 1327/1327 - 8s - loss: 0.4390 - val_loss: 0.4527 - 8s/epoch - 6ms/step
# Epoch 26/100
# 1327/1327 - 8s - loss: 0.4378 - val_loss: 0.4483 - 8s/epoch - 6ms/step
# Epoch 27/100
# 1327/1327 - 8s - loss: 0.4335 - val_loss: 0.4535 - 8s/epoch - 6ms/step
# Epoch 28/100
# 1327/1327 - 8s - loss: 0.4311 - val_loss: 0.4649 - 8s/epoch - 6ms/step
# Epoch 29/100
# 1327/1327 - 8s - loss: 0.4298 - val_loss: 0.4611 - 8s/epoch - 6ms/step
# Epoch 30/100
# 1327/1327 - 8s - loss: 0.4303 - val_loss: 0.4609 - 8s/epoch - 6ms/step
# Epoch 31/100
# 1327/1327 - 8s - loss: 0.4284 - val_loss: 0.4436 - 8s/epoch - 6ms/step
# Epoch 32/100
# 1327/1327 - 8s - loss: 0.4270 - val_loss: 0.4449 - 8s/epoch - 6ms/step
# Epoch 33/100
# 1327/1327 - 8s - loss: 0.4221 - val_loss: 0.4390 - 8s/epoch - 6ms/step
# Epoch 34/100
# 1327/1327 - 8s - loss: 0.4226 - val_loss: 0.4523 - 8s/epoch - 6ms/step
# Epoch 35/100
# 1327/1327 - 8s - loss: 0.4216 - val_loss: 0.4373 - 8s/epoch - 6ms/step
# Epoch 36/100
# 1327/1327 - 9s - loss: 0.4218 - val_loss: 0.4489 - 9s/epoch - 7ms/step
# Epoch 37/100
# 1327/1327 - 9s - loss: 0.4197 - val_loss: 0.4531 - 9s/epoch - 7ms/step
# Epoch 38/100
# 1327/1327 - 9s - loss: 0.4170 - val_loss: 0.4368 - 9s/epoch - 7ms/step
# Epoch 39/100
# 1327/1327 - 9s - loss: 0.4163 - val_loss: 0.4571 - 9s/epoch - 7ms/step
# Epoch 40/100
# 1327/1327 - 9s - loss: 0.4168 - val_loss: 0.4419 - 9s/epoch - 7ms/step
# Epoch 41/100
# 1327/1327 - 9s - loss: 0.4124 - val_loss: 0.4391 - 9s/epoch - 7ms/step
# Epoch 42/100
# 1327/1327 - 9s - loss: 0.4126 - val_loss: 0.4418 - 9s/epoch - 7ms/step
# Epoch 43/100
# 1327/1327 - 9s - loss: 0.4131 - val_loss: 0.4412 - 9s/epoch - 7ms/step
# Epoch 44/100
# 1327/1327 - 9s - loss: 0.4099 - val_loss: 0.4449 - 9s/epoch - 7ms/step
# Epoch 45/100
# 1327/1327 - 8s - loss: 0.4085 - val_loss: 0.4540 - 8s/epoch - 6ms/step
# Epoch 46/100
# 1327/1327 - 8s - loss: 0.4106 - val_loss: 0.4421 - 8s/epoch - 6ms/step
# Epoch 47/100
# 1327/1327 - 8s - loss: 0.4074 - val_loss: 0.4446 - 8s/epoch - 6ms/step
# Epoch 48/100
# 1327/1327 - 8s - loss: 0.4084 - val_loss: 0.4322 - 8s/epoch - 6ms/step
# Epoch 49/100
# 1327/1327 - 8s - loss: 0.4044 - val_loss: 0.4472 - 8s/epoch - 6ms/step
# Epoch 50/100
# 1327/1327 - 8s - loss: 0.4056 - val_loss: 0.4328 - 8s/epoch - 6ms/step
# Epoch 51/100
# 1327/1327 - 8s - loss: 0.4045 - val_loss: 0.4335 - 8s/epoch - 6ms/step
# Epoch 52/100
# 1327/1327 - 8s - loss: 0.4051 - val_loss: 0.4358 - 8s/epoch - 6ms/step
# Epoch 53/100
# 1327/1327 - 8s - loss: 0.4020 - val_loss: 0.4297 - 8s/epoch - 6ms/step
# Epoch 54/100
# 1327/1327 - 8s - loss: 0.4011 - val_loss: 0.4300 - 8s/epoch - 6ms/step
# Epoch 55/100
# 1327/1327 - 8s - loss: 0.4026 - val_loss: 0.4314 - 8s/epoch - 6ms/step
# Epoch 56/100
# 1327/1327 - 8s - loss: 0.4015 - val_loss: 0.4352 - 8s/epoch - 6ms/step
# Epoch 57/100
# 1327/1327 - 8s - loss: 0.4015 - val_loss: 0.4292 - 8s/epoch - 6ms/step
# Epoch 58/100
# 1327/1327 - 8s - loss: 0.3995 - val_loss: 0.4404 - 8s/epoch - 6ms/step
# Epoch 59/100
# 1327/1327 - 8s - loss: 0.3982 - val_loss: 0.4493 - 8s/epoch - 6ms/step
# Epoch 60/100
# 1327/1327 - 9s - loss: 0.3981 - val_loss: 0.4340 - 9s/epoch - 6ms/step
# Epoch 61/100
# 1327/1327 - 9s - loss: 0.3969 - val_loss: 0.4305 - 9s/epoch - 7ms/step
# Epoch 62/100
# 1327/1327 - 9s - loss: 0.3972 - val_loss: 0.4305 - 9s/epoch - 6ms/step
# Epoch 63/100
# 1327/1327 - 9s - loss: 0.3967 - val_loss: 0.4307 - 9s/epoch - 6ms/step
# Epoch 64/100
# 1327/1327 - 9s - loss: 0.3946 - val_loss: 0.4273 - 9s/epoch - 6ms/step
# Epoch 65/100
# 1327/1327 - 9s - loss: 0.3953 - val_loss: 0.4322 - 9s/epoch - 6ms/step
# Epoch 66/100
# 1327/1327 - 9s - loss: 0.3930 - val_loss: 0.4448 - 9s/epoch - 7ms/step
# Epoch 67/100
# 1327/1327 - 9s - loss: 0.3928 - val_loss: 0.4244 - 9s/epoch - 7ms/step
# Epoch 68/100
# 1327/1327 - 9s - loss: 0.3920 - val_loss: 0.4317 - 9s/epoch - 6ms/step
# Epoch 69/100
# 1327/1327 - 8s - loss: 0.3908 - val_loss: 0.4338 - 8s/epoch - 6ms/step
# Epoch 70/100
# 1327/1327 - 9s - loss: 0.3912 - val_loss: 0.4262 - 9s/epoch - 6ms/step
# Epoch 71/100
# 1327/1327 - 9s - loss: 0.3911 - val_loss: 0.4303 - 9s/epoch - 6ms/step
# Epoch 72/100
# 1327/1327 - 9s - loss: 0.3894 - val_loss: 0.4351 - 9s/epoch - 6ms/step
# Epoch 73/100
# 1327/1327 - 9s - loss: 0.3919 - val_loss: 0.4299 - 9s/epoch - 6ms/step
# Epoch 74/100
# 1327/1327 - 9s - loss: 0.3875 - val_loss: 0.4218 - 9s/epoch - 6ms/step
# Epoch 75/100
# 1327/1327 - 9s - loss: 0.3909 - val_loss: 0.4258 - 9s/epoch - 6ms/step
# Epoch 76/100
# 1327/1327 - 9s - loss: 0.3880 - val_loss: 0.4291 - 9s/epoch - 6ms/step
# Epoch 77/100
# 1327/1327 - 9s - loss: 0.3864 - val_loss: 0.4456 - 9s/epoch - 6ms/step
# Epoch 78/100
# 1327/1327 - 9s - loss: 0.3849 - val_loss: 0.4341 - 9s/epoch - 6ms/step
# Epoch 79/100
# 1327/1327 - 9s - loss: 0.3844 - val_loss: 0.4357 - 9s/epoch - 6ms/step
# Epoch 80/100
# 1327/1327 - 9s - loss: 0.3846 - val_loss: 0.4238 - 9s/epoch - 6ms/step
# Epoch 81/100
# 1327/1327 - 9s - loss: 0.3873 - val_loss: 0.4230 - 9s/epoch - 6ms/step
# Epoch 82/100
# 1327/1327 - 9s - loss: 0.3841 - val_loss: 0.4186 - 9s/epoch - 6ms/step
# Epoch 83/100
# 1327/1327 - 8s - loss: 0.3843 - val_loss: 0.4305 - 8s/epoch - 6ms/step
# Epoch 84/100
# 1327/1327 - 8s - loss: 0.3831 - val_loss: 0.4259 - 8s/epoch - 6ms/step
# Epoch 85/100
# 1327/1327 - 9s - loss: 0.3837 - val_loss: 0.4286 - 9s/epoch - 6ms/step
# Epoch 86/100
# 1327/1327 - 9s - loss: 0.3822 - val_loss: 0.4205 - 9s/epoch - 6ms/step
# Epoch 87/100
# 1327/1327 - 8s - loss: 0.3816 - val_loss: 0.4240 - 8s/epoch - 6ms/step
# Epoch 88/100
# 1327/1327 - 8s - loss: 0.3823 - val_loss: 0.4417 - 8s/epoch - 6ms/step
# Epoch 89/100
# 1327/1327 - 9s - loss: 0.3806 - val_loss: 0.4225 - 9s/epoch - 6ms/step
# Epoch 90/100
# 1327/1327 - 8s - loss: 0.3807 - val_loss: 0.4249 - 8s/epoch - 6ms/step
# Epoch 91/100
# 1327/1327 - 8s - loss: 0.3801 - val_loss: 0.4209 - 8s/epoch - 6ms/step
# Epoch 92/100
# 1327/1327 - 9s - loss: 0.3783 - val_loss: 0.4228 - 9s/epoch - 6ms/step
# Epoch 1/100
# 1327/1327 - 16s - loss: 1.8228 - val_loss: 1.2460 - 16s/epoch - 12ms/step
# Epoch 2/100
# 1327/1327 - 9s - loss: 1.0841 - val_loss: 0.9377 - 9s/epoch - 6ms/step
# Epoch 3/100
# 1327/1327 - 9s - loss: 0.8989 - val_loss: 0.8215 - 9s/epoch - 6ms/step
# Epoch 4/100
# 1327/1327 - 9s - loss: 0.8409 - val_loss: 0.7777 - 9s/epoch - 6ms/step
# Epoch 5/100
# 1327/1327 - 8s - loss: 0.7999 - val_loss: 0.7869 - 8s/epoch - 6ms/step
# Epoch 6/100
# 1327/1327 - 9s - loss: 0.7731 - val_loss: 0.7334 - 9s/epoch - 6ms/step
# Epoch 7/100
# 1327/1327 - 9s - loss: 0.7489 - val_loss: 0.7436 - 9s/epoch - 6ms/step
# Epoch 8/100
# 1327/1327 - 8s - loss: 0.7305 - val_loss: 0.7080 - 8s/epoch - 6ms/step
# Epoch 9/100
# 1327/1327 - 8s - loss: 0.7174 - val_loss: 0.7066 - 8s/epoch - 6ms/step
# Epoch 10/100
# 1327/1327 - 9s - loss: 0.7049 - val_loss: 0.6821 - 9s/epoch - 6ms/step
# Epoch 11/100
# 1327/1327 - 9s - loss: 0.6910 - val_loss: 0.6746 - 9s/epoch - 7ms/step
# Epoch 12/100
# 1327/1327 - 9s - loss: 0.6762 - val_loss: 0.6714 - 9s/epoch - 7ms/step
# Epoch 13/100
# 1327/1327 - 9s - loss: 0.6717 - val_loss: 0.6723 - 9s/epoch - 7ms/step
# Epoch 14/100
# 1327/1327 - 9s - loss: 0.6667 - val_loss: 0.6778 - 9s/epoch - 7ms/step
# Epoch 15/100
# 1327/1327 - 9s - loss: 0.6509 - val_loss: 0.7022 - 9s/epoch - 7ms/step
# Epoch 16/100
# 1327/1327 - 9s - loss: 0.6396 - val_loss: 0.6584 - 9s/epoch - 7ms/step
# Epoch 17/100
# 1327/1327 - 9s - loss: 0.6325 - val_loss: 0.6423 - 9s/epoch - 7ms/step
# Epoch 18/100
# 1327/1327 - 9s - loss: 0.6254 - val_loss: 0.6951 - 9s/epoch - 7ms/step
# Epoch 19/100
# 1327/1327 - 9s - loss: 0.6186 - val_loss: 0.6489 - 9s/epoch - 7ms/step
# Epoch 20/100
# 1327/1327 - 9s - loss: 0.6131 - val_loss: 0.6421 - 9s/epoch - 7ms/step
# Epoch 21/100
# 1327/1327 - 9s - loss: 0.6065 - val_loss: 0.6322 - 9s/epoch - 7ms/step
# Epoch 22/100
# 1327/1327 - 9s - loss: 0.6018 - val_loss: 0.6224 - 9s/epoch - 7ms/step
# Epoch 23/100
# 1327/1327 - 9s - loss: 0.5956 - val_loss: 0.6485 - 9s/epoch - 7ms/step
# Epoch 24/100
# 1327/1327 - 9s - loss: 0.5931 - val_loss: 0.6216 - 9s/epoch - 7ms/step
# Epoch 25/100
# 1327/1327 - 9s - loss: 0.5797 - val_loss: 0.6242 - 9s/epoch - 7ms/step
# Epoch 26/100
# 1327/1327 - 9s - loss: 0.5847 - val_loss: 0.6099 - 9s/epoch - 7ms/step
# Epoch 27/100
# 1327/1327 - 9s - loss: 0.5753 - val_loss: 0.6375 - 9s/epoch - 7ms/step
# Epoch 28/100
# 1327/1327 - 9s - loss: 0.5718 - val_loss: 0.6125 - 9s/epoch - 7ms/step
# Epoch 29/100
# 1327/1327 - 9s - loss: 0.5691 - val_loss: 0.6185 - 9s/epoch - 7ms/step
# Epoch 30/100
# 1327/1327 - 10s - loss: 0.5624 - val_loss: 0.6169 - 10s/epoch - 7ms/step
# Epoch 31/100
# 1327/1327 - 9s - loss: 0.5561 - val_loss: 0.6104 - 9s/epoch - 7ms/step
# Epoch 32/100
# 1327/1327 - 10s - loss: 0.5573 - val_loss: 0.6121 - 10s/epoch - 7ms/step
# Epoch 33/100
# 1327/1327 - 10s - loss: 0.5511 - val_loss: 0.6060 - 10s/epoch - 7ms/step
# Epoch 34/100
# 1327/1327 - 10s - loss: 0.5525 - val_loss: 0.6189 - 10s/epoch - 7ms/step
# Epoch 35/100
# 1327/1327 - 9s - loss: 0.5442 - val_loss: 0.6123 - 9s/epoch - 7ms/step
# Epoch 36/100
# 1327/1327 - 9s - loss: 0.5502 - val_loss: 0.6232 - 9s/epoch - 7ms/step
# Epoch 37/100
# 1327/1327 - 9s - loss: 0.5380 - val_loss: 0.6196 - 9s/epoch - 7ms/step
# Epoch 38/100
# 1327/1327 - 9s - loss: 0.5401 - val_loss: 0.6167 - 9s/epoch - 7ms/step
# Epoch 39/100
# 1327/1327 - 9s - loss: 0.5340 - val_loss: 0.6173 - 9s/epoch - 7ms/step
# Epoch 40/100
# 1327/1327 - 8s - loss: 0.5328 - val_loss: 0.6035 - 8s/epoch - 6ms/step
# Epoch 41/100
# 1327/1327 - 9s - loss: 0.5344 - val_loss: 0.6333 - 9s/epoch - 7ms/step
# Epoch 42/100
# 1327/1327 - 9s - loss: 0.5297 - val_loss: 0.6017 - 9s/epoch - 7ms/step
# Epoch 43/100
# 1327/1327 - 9s - loss: 0.5251 - val_loss: 0.6095 - 9s/epoch - 7ms/step
# Epoch 44/100
# 1327/1327 - 9s - loss: 0.5249 - val_loss: 0.6111 - 9s/epoch - 7ms/step
# Epoch 45/100
# 1327/1327 - 9s - loss: 0.5178 - val_loss: 0.6425 - 9s/epoch - 7ms/step
# Epoch 46/100
# 1327/1327 - 9s - loss: 0.5173 - val_loss: 0.6010 - 9s/epoch - 7ms/step
# Epoch 47/100
# 1327/1327 - 9s - loss: 0.5126 - val_loss: 0.6126 - 9s/epoch - 7ms/step
# Epoch 48/100
# 1327/1327 - 9s - loss: 0.5133 - val_loss: 0.6185 - 9s/epoch - 7ms/step
# Epoch 49/100
# 1327/1327 - 9s - loss: 0.5100 - val_loss: 0.6095 - 9s/epoch - 7ms/step
# Epoch 50/100
# 1327/1327 - 9s - loss: 0.5091 - val_loss: 0.6147 - 9s/epoch - 7ms/step
# Epoch 51/100
# 1327/1327 - 9s - loss: 0.5145 - val_loss: 0.6068 - 9s/epoch - 7ms/step
# Epoch 52/100
# 1327/1327 - 9s - loss: 0.5021 - val_loss: 0.6108 - 9s/epoch - 6ms/step
# Epoch 53/100
# 1327/1327 - 9s - loss: 0.5011 - val_loss: 0.6111 - 9s/epoch - 6ms/step
# Epoch 54/100
# 1327/1327 - 9s - loss: 0.5005 - val_loss: 0.6012 - 9s/epoch - 7ms/step
# Epoch 55/100
# 1327/1327 - 9s - loss: 0.5059 - val_loss: 0.6130 - 9s/epoch - 6ms/step
# Epoch 56/100
# 1327/1327 - 9s - loss: 0.4984 - val_loss: 0.5950 - 9s/epoch - 7ms/step
# Epoch 57/100
# 1327/1327 - 10s - loss: 0.4977 - val_loss: 0.6263 - 10s/epoch - 7ms/step
# Epoch 58/100
# 1327/1327 - 9s - loss: 0.4924 - val_loss: 0.6004 - 9s/epoch - 7ms/step
# Epoch 59/100
# 1327/1327 - 9s - loss: 0.4957 - val_loss: 0.6018 - 9s/epoch - 6ms/step
# Epoch 60/100
# 1327/1327 - 9s - loss: 0.4947 - val_loss: 0.6231 - 9s/epoch - 6ms/step
# Epoch 61/100
# 1327/1327 - 9s - loss: 0.4850 - val_loss: 0.5994 - 9s/epoch - 7ms/step
# Epoch 62/100
# 1327/1327 - 9s - loss: 0.4912 - val_loss: 0.6088 - 9s/epoch - 7ms/step
# Epoch 63/100
# 1327/1327 - 9s - loss: 0.4871 - val_loss: 0.6072 - 9s/epoch - 7ms/step
# Epoch 64/100
# 1327/1327 - 9s - loss: 0.4875 - val_loss: 0.6109 - 9s/epoch - 7ms/step
# Epoch 65/100
# 1327/1327 - 9s - loss: 0.4834 - val_loss: 0.5983 - 9s/epoch - 7ms/step
# Epoch 66/100
# 1327/1327 - 9s - loss: 0.4851 - val_loss: 0.5993 - 9s/epoch - 7ms/step
# Epoch 1/100
# 1327/1327 - 10s - loss: 0.5971 - val_loss: 0.4483 - 10s/epoch - 8ms/step
# Epoch 2/100
# 1327/1327 - 8s - loss: 0.4160 - val_loss: 0.3866 - 8s/epoch - 6ms/step
# Epoch 3/100
# 1327/1327 - 9s - loss: 0.3811 - val_loss: 0.3690 - 9s/epoch - 6ms/step
# Epoch 4/100
# 1327/1327 - 8s - loss: 0.3623 - val_loss: 0.3521 - 8s/epoch - 6ms/step
# Epoch 5/100
# 1327/1327 - 8s - loss: 0.3490 - val_loss: 0.3364 - 8s/epoch - 6ms/step
# Epoch 6/100
# 1327/1327 - 8s - loss: 0.3393 - val_loss: 0.3301 - 8s/epoch - 6ms/step
# Epoch 7/100
# 1327/1327 - 8s - loss: 0.3306 - val_loss: 0.3220 - 8s/epoch - 6ms/step
# Epoch 8/100
# 1327/1327 - 8s - loss: 0.3238 - val_loss: 0.3241 - 8s/epoch - 6ms/step
# Epoch 9/100
# 1327/1327 - 9s - loss: 0.3187 - val_loss: 0.3197 - 9s/epoch - 7ms/step
# Epoch 10/100
# 1327/1327 - 8s - loss: 0.3148 - val_loss: 0.3116 - 8s/epoch - 6ms/step
# Epoch 11/100
# 1327/1327 - 8s - loss: 0.3126 - val_loss: 0.3061 - 8s/epoch - 6ms/step
# Epoch 12/100
# 1327/1327 - 8s - loss: 0.3076 - val_loss: 0.3070 - 8s/epoch - 6ms/step
# Epoch 13/100
# 1327/1327 - 8s - loss: 0.3052 - val_loss: 0.3032 - 8s/epoch - 6ms/step
# Epoch 14/100
# 1327/1327 - 8s - loss: 0.3011 - val_loss: 0.3077 - 8s/epoch - 6ms/step
# Epoch 15/100
# 1327/1327 - 8s - loss: 0.3009 - val_loss: 0.3087 - 8s/epoch - 6ms/step
# Epoch 16/100
# 1327/1327 - 8s - loss: 0.2978 - val_loss: 0.2991 - 8s/epoch - 6ms/step
# Epoch 17/100
# 1327/1327 - 8s - loss: 0.2956 - val_loss: 0.3001 - 8s/epoch - 6ms/step
# Epoch 18/100
# 1327/1327 - 8s - loss: 0.2953 - val_loss: 0.2992 - 8s/epoch - 6ms/step
# Epoch 19/100
# 1327/1327 - 8s - loss: 0.2934 - val_loss: 0.2976 - 8s/epoch - 6ms/step
# Epoch 20/100
# 1327/1327 - 8s - loss: 0.2905 - val_loss: 0.2965 - 8s/epoch - 6ms/step
# Epoch 21/100
# 1327/1327 - 8s - loss: 0.2894 - val_loss: 0.2948 - 8s/epoch - 6ms/step
# Epoch 22/100
# 1327/1327 - 8s - loss: 0.2877 - val_loss: 0.2974 - 8s/epoch - 6ms/step
# Epoch 23/100
# 1327/1327 - 8s - loss: 0.2877 - val_loss: 0.2918 - 8s/epoch - 6ms/step
# Epoch 24/100
# 1327/1327 - 8s - loss: 0.2865 - val_loss: 0.2907 - 8s/epoch - 6ms/step
# Epoch 25/100
# 1327/1327 - 8s - loss: 0.2857 - val_loss: 0.3002 - 8s/epoch - 6ms/step
# Epoch 26/100
# 1327/1327 - 8s - loss: 0.2846 - val_loss: 0.2920 - 8s/epoch - 6ms/step
# Epoch 27/100
# 1327/1327 - 8s - loss: 0.2833 - val_loss: 0.3000 - 8s/epoch - 6ms/step
# Epoch 28/100
# 1327/1327 - 8s - loss: 0.2834 - val_loss: 0.2954 - 8s/epoch - 6ms/step
# Epoch 29/100
# 1327/1327 - 8s - loss: 0.2809 - val_loss: 0.2871 - 8s/epoch - 6ms/step
# Epoch 30/100
# 1327/1327 - 8s - loss: 0.2804 - val_loss: 0.3025 - 8s/epoch - 6ms/step
# Epoch 31/100
# 1327/1327 - 8s - loss: 0.2789 - val_loss: 0.2974 - 8s/epoch - 6ms/step
# Epoch 32/100
# ...
# Epoch 49/100
# 1327/1327 - 9s - loss: 0.2728 - val_loss: 0.2861 - 9s/epoch - 6ms/step
# Epoch 50/100
# 1327/1327 - 9s - loss: 0.2721 - val_loss: 0.2933 - 9s/epoch - 6ms/step
# Epoch 51/100
# 1327/1327 - 9s - loss: 0.2725 - val_loss: 0.2832 - 9s/epoch - 6ms/step
# Epoch 52/100
# 1327/1327 - 9s - loss: 0.2728 - val_loss: 0.2868 - 9s/epoch - 6ms/step
# Epoch 53/100
# 1327/1327 - 9s - loss: 0.2713 - val_loss: 0.2815 - 9s/epoch - 6ms/step
# Epoch 54/100
# 1327/1327 - 9s - loss: 0.2702 - val_loss: 0.2897 - 9s/epoch - 6ms/step
# Epoch 55/100
# 1327/1327 - 9s - loss: 0.2709 - val_loss: 0.2904 - 9s/epoch - 6ms/step
# Epoch 56/100
# 1327/1327 - 9s - loss: 0.2691 - val_loss: 0.2860 - 9s/epoch - 6ms/step
# Epoch 57/100
# 1327/1327 - 9s - loss: 0.2700 - val_loss: 0.2930 - 9s/epoch - 6ms/step
# Epoch 58/100
# 1327/1327 - 9s - loss: 0.2689 - val_loss: 0.2836 - 9s/epoch - 6ms/step
# Epoch 59/100
# 1327/1327 - 9s - loss: 0.2683 - val_loss: 0.2833 - 9s/epoch - 6ms/step
# Epoch 60/100
# 1327/1327 - 9s - loss: 0.2667 - val_loss: 0.2836 - 9s/epoch - 6ms/step
# Epoch 61/100
# 1327/1327 - 9s - loss: 0.2675 - val_loss: 0.2808 - 9s/epoch - 6ms/step
# Epoch 62/100
# 1327/1327 - 9s - loss: 0.2663 - val_loss: 0.2830 - 9s/epoch - 6ms/step
# Epoch 63/100
# 1327/1327 - 9s - loss: 0.2681 - val_loss: 0.2870 - 9s/epoch - 6ms/step
# Epoch 64/100
# 1327/1327 - 9s - loss: 0.2665 - val_loss: 0.2918 - 9s/epoch - 6ms/step
# Epoch 65/100
# 1327/1327 - 9s - loss: 0.2666 - val_loss: 0.2836 - 9s/epoch - 7ms/step
# Epoch 66/100
# 1327/1327 - 9s - loss: 0.2661 - val_loss: 0.2838 - 9s/epoch - 6ms/step
# Epoch 67/100
# 1327/1327 - 9s - loss: 0.2657 - val_loss: 0.2804 - 9s/epoch - 6ms/step
# Epoch 68/100
# 1327/1327 - 9s - loss: 0.2652 - val_loss: 0.2884 - 9s/epoch - 6ms/step
# Epoch 69/100
# 1327/1327 - 9s - loss: 0.2658 - val_loss: 0.2794 - 9s/epoch - 6ms/step
# Epoch 70/100
# 1327/1327 - 9s - loss: 0.2648 - val_loss: 0.2836 - 9s/epoch - 7ms/step
# Epoch 71/100
# 1327/1327 - 9s - loss: 0.2643 - val_loss: 0.2788 - 9s/epoch - 7ms/step
# Epoch 72/100
# 1327/1327 - 9s - loss: 0.2647 - val_loss: 0.2821 - 9s/epoch - 7ms/step
# Epoch 73/100
# 1327/1327 - 9s - loss: 0.2640 - val_loss: 0.2812 - 9s/epoch - 7ms/step
# Epoch 74/100
# 1327/1327 - 9s - loss: 0.2628 - val_loss: 0.2870 - 9s/epoch - 7ms/step
# Epoch 75/100
# 1327/1327 - 9s - loss: 0.2633 - val_loss: 0.2867 - 9s/epoch - 7ms/step
# Epoch 76/100
# 1327/1327 - 9s - loss: 0.2619 - val_loss: 0.2763 - 9s/epoch - 7ms/step
# Epoch 77/100
# 1327/1327 - 9s - loss: 0.2628 - val_loss: 0.2793 - 9s/epoch - 7ms/step
# Epoch 78/100
# 1327/1327 - 9s - loss: 0.2615 - val_loss: 0.2815 - 9s/epoch - 7ms/step
# Epoch 79/100
# 1327/1327 - 9s - loss: 0.2609 - val_loss: 0.2833 - 9s/epoch - 7ms/step
# Epoch 80/100
# 1327/1327 - 9s - loss: 0.2624 - val_loss: 0.2845 - 9s/epoch - 7ms/step
# Epoch 81/100
# 1327/1327 - 9s - loss: 0.2609 - val_loss: 0.2802 - 9s/epoch - 7ms/step
# Epoch 82/100
# 1327/1327 - 9s - loss: 0.2602 - val_loss: 0.2817 - 9s/epoch - 7ms/step
# Epoch 83/100
# 1327/1327 - 9s - loss: 0.2612 - val_loss: 0.2790 - 9s/epoch - 7ms/step
# Epoch 84/100
# 1327/1327 - 9s - loss: 0.2587 - val_loss: 0.2763 - 9s/epoch - 7ms/step
# Epoch 85/100
# 1327/1327 - 9s - loss: 0.2602 - val_loss: 0.2775 - 9s/epoch - 6ms/step
# Epoch 86/100
# 1327/1327 - 9s - loss: 0.2601 - val_loss: 0.2759 - 9s/epoch - 6ms/step
# Epoch 87/100
# 1327/1327 - 9s - loss: 0.2590 - val_loss: 0.2790 - 9s/epoch - 6ms/step
# Epoch 88/100
# 1327/1327 - 9s - loss: 0.2599 - val_loss: 0.2805 - 9s/epoch - 6ms/step
# Epoch 89/100
# 1327/1327 - 9s - loss: 0.2591 - val_loss: 0.2806 - 9s/epoch - 6ms/step
# Epoch 90/100
# 1327/1327 - 9s - loss: 0.2591 - val_loss: 0.2785 - 9s/epoch - 6ms/step
# Epoch 91/100
# 1327/1327 - 9s - loss: 0.2584 - val_loss: 0.2754 - 9s/epoch - 6ms/step
# Epoch 92/100
# 1327/1327 - 9s - loss: 0.2580 - val_loss: 0.2810 - 9s/epoch - 6ms/step
# Epoch 93/100
# 1327/1327 - 9s - loss: 0.2582 - val_loss: 0.2769 - 9s/epoch - 6ms/step
# Epoch 94/100
# 1327/1327 - 9s - loss: 0.2579 - val_loss: 0.2802 - 9s/epoch - 6ms/step
# Epoch 95/100
# 1327/1327 - 9s - loss: 0.2571 - val_loss: 0.2767 - 9s/epoch - 6ms/step
# Epoch 96/100
# 1327/1327 - 9s - loss: 0.2570 - val_loss: 0.2792 - 9s/epoch - 6ms/step
# Epoch 97/100
# 1327/1327 - 9s - loss: 0.2574 - val_loss: 0.2781 - 9s/epoch - 6ms/step
# Epoch 98/100
# 1327/1327 - 9s - loss: 0.2572 - val_loss: 0.2776 - 9s/epoch - 6ms/step
# Epoch 99/100
# 1327/1327 - 9s - loss: 0.2558 - val_loss: 0.2772 - 9s/epoch - 6ms/step
# Epoch 100/100
# 1327/1327 - 9s - loss: 0.2560 - val_loss: 0.2791 - 9s/epoch - 6ms/step
# Epoch 1/100
# 1327/1327 - 17s - loss: 1.0164 - val_loss: 0.7164 - 17s/epoch - 13ms/step
# Epoch 2/100
# 1327/1327 - 9s - loss: 0.6604 - val_loss: 0.6012 - 9s/epoch - 6ms/step
# Epoch 3/100
# 1327/1327 - 9s - loss: 0.5961 - val_loss: 0.5683 - 9s/epoch - 6ms/step
# Epoch 4/100
# 1327/1327 - 9s - loss: 0.5620 - val_loss: 0.5472 - 9s/epoch - 6ms/step
# Epoch 5/100
# 1327/1327 - 9s - loss: 0.5447 - val_loss: 0.5415 - 9s/epoch - 6ms/step
# Epoch 6/100
# 1327/1327 - 8s - loss: 0.5290 - val_loss: 0.5253 - 8s/epoch - 6ms/step
# Epoch 7/100
# 1327/1327 - 8s - loss: 0.5198 - val_loss: 0.4992 - 8s/epoch - 6ms/step
# Epoch 8/100
# 1327/1327 - 9s - loss: 0.5093 - val_loss: 0.4971 - 9s/epoch - 6ms/step
# Epoch 9/100
# 1327/1327 - 9s - loss: 0.5008 - val_loss: 0.4963 - 9s/epoch - 6ms/step
# Epoch 10/100
# 1327/1327 - 8s - loss: 0.4906 - val_loss: 0.4892 - 8s/epoch - 6ms/step
# Epoch 11/100
# 1327/1327 - 9s - loss: 0.4865 - val_loss: 0.4927 - 9s/epoch - 6ms/step
# Epoch 12/100
# 1327/1327 - 8s - loss: 0.4807 - val_loss: 0.4808 - 8s/epoch - 6ms/step
# Epoch 13/100
# 1327/1327 - 8s - loss: 0.4744 - val_loss: 0.4706 - 8s/epoch - 6ms/step
# Epoch 14/100
# 1327/1327 - 9s - loss: 0.4697 - val_loss: 0.4681 - 9s/epoch - 6ms/step
# Epoch 15/100
# 1327/1327 - 8s - loss: 0.4650 - val_loss: 0.4850 - 8s/epoch - 6ms/step
# Epoch 16/100
# 1327/1327 - 9s - loss: 0.4615 - val_loss: 0.4693 - 9s/epoch - 6ms/step
# Epoch 17/100
# 1327/1327 - 8s - loss: 0.4556 - val_loss: 0.4728 - 8s/epoch - 6ms/step
# Epoch 18/100
# 1327/1327 - 9s - loss: 0.4531 - val_loss: 0.4685 - 9s/epoch - 6ms/step
# Epoch 19/100
# 1327/1327 - 9s - loss: 0.4516 - val_loss: 0.4597 - 9s/epoch - 6ms/step
# Epoch 20/100
# 1327/1327 - 9s - loss: 0.4494 - val_loss: 0.4791 - 9s/epoch - 7ms/step
# Epoch 21/100
# 1327/1327 - 9s - loss: 0.4434 - val_loss: 0.4539 - 9s/epoch - 6ms/step
# Epoch 22/100
# 1327/1327 - 9s - loss: 0.4417 - val_loss: 0.4553 - 9s/epoch - 6ms/step
# Epoch 23/100
# 1327/1327 - 9s - loss: 0.4427 - val_loss: 0.4471 - 9s/epoch - 6ms/step
# Epoch 24/100
# 1327/1327 - 9s - loss: 0.4374 - val_loss: 0.4514 - 9s/epoch - 6ms/step
# Epoch 25/100
# 1327/1327 - 9s - loss: 0.4353 - val_loss: 0.4581 - 9s/epoch - 6ms/step
# Epoch 26/100
# 1327/1327 - 9s - loss: 0.4338 - val_loss: 0.4501 - 9s/epoch - 6ms/step
# Epoch 27/100
# 1327/1327 - 9s - loss: 0.4310 - val_loss: 0.4461 - 9s/epoch - 6ms/step
# Epoch 28/100
# 1327/1327 - 9s - loss: 0.4303 - val_loss: 0.4549 - 9s/epoch - 6ms/step
# Epoch 29/100
# 1327/1327 - 9s - loss: 0.4263 - val_loss: 0.4399 - 9s/epoch - 6ms/step
# Epoch 30/100
# 1327/1327 - 9s - loss: 0.4269 - val_loss: 0.4549 - 9s/epoch - 7ms/step
# Epoch 31/100
# 1327/1327 - 9s - loss: 0.4239 - val_loss: 0.4452 - 9s/epoch - 7ms/step
# Epoch 32/100
# 1327/1327 - 9s - loss: 0.4239 - val_loss: 0.4512 - 9s/epoch - 7ms/step
# Epoch 33/100
# 1327/1327 - 9s - loss: 0.4228 - val_loss: 0.4584 - 9s/epoch - 7ms/step
# Epoch 34/100
# 1327/1327 - 9s - loss: 0.4219 - val_loss: 0.4461 - 9s/epoch - 7ms/step
# Epoch 35/100
# 1327/1327 - 9s - loss: 0.4200 - val_loss: 0.4526 - 9s/epoch - 7ms/step
# Epoch 36/100
# 1327/1327 - 9s - loss: 0.4187 - val_loss: 0.4381 - 9s/epoch - 6ms/step
# Epoch 37/100
# 1327/1327 - 9s - loss: 0.4161 - val_loss: 0.4473 - 9s/epoch - 6ms/step
# Epoch 38/100
# 1327/1327 - 9s - loss: 0.4153 - val_loss: 0.4380 - 9s/epoch - 6ms/step
# Epoch 39/100
# 1327/1327 - 9s - loss: 0.4135 - val_loss: 0.4372 - 9s/epoch - 6ms/step
# Epoch 40/100
# 1327/1327 - 8s - loss: 0.4128 - val_loss: 0.4439 - 8s/epoch - 6ms/step
# Epoch 41/100
# 1327/1327 - 9s - loss: 0.4127 - val_loss: 0.4360 - 9s/epoch - 6ms/step
# Epoch 42/100
# 1327/1327 - 8s - loss: 0.4110 - val_loss: 0.4492 - 8s/epoch - 6ms/step
# Epoch 43/100
# 1327/1327 - 9s - loss: 0.4113 - val_loss: 0.4357 - 9s/epoch - 6ms/step
# Epoch 44/100
# 1327/1327 - 9s - loss: 0.4100 - val_loss: 0.4386 - 9s/epoch - 6ms/step
# Epoch 45/100
# 1327/1327 - 9s - loss: 0.4077 - val_loss: 0.4504 - 9s/epoch - 6ms/step
# Epoch 46/100
# 1327/1327 - 8s - loss: 0.4070 - val_loss: 0.4457 - 8s/epoch - 6ms/step
# Epoch 47/100
# 1327/1327 - 8s - loss: 0.4084 - val_loss: 0.4522 - 8s/epoch - 6ms/step
# Epoch 48/100
# 1327/1327 - 8s - loss: 0.4031 - val_loss: 0.4311 - 8s/epoch - 6ms/step
# Epoch 49/100
# 1327/1327 - 9s - loss: 0.4022 - val_loss: 0.4356 - 9s/epoch - 6ms/step
# Epoch 50/100
# 1327/1327 - 9s - loss: 0.4042 - val_loss: 0.4377 - 9s/epoch - 6ms/step
# Epoch 51/100
# 1327/1327 - 9s - loss: 0.4026 - val_loss: 0.4586 - 9s/epoch - 6ms/step
# Epoch 52/100
# 1327/1327 - 9s - loss: 0.4004 - val_loss: 0.4344 - 9s/epoch - 6ms/step
# Epoch 53/100
# 1327/1327 - 9s - loss: 0.3997 - val_loss: 0.4310 - 9s/epoch - 6ms/step
# Epoch 54/100
# 1327/1327 - 8s - loss: 0.3986 - val_loss: 0.4518 - 8s/epoch - 6ms/step
# Epoch 55/100
# 1327/1327 - 8s - loss: 0.3984 - val_loss: 0.4266 - 8s/epoch - 6ms/step
# Epoch 56/100
# 1327/1327 - 8s - loss: 0.4006 - val_loss: 0.4301 - 8s/epoch - 6ms/step
# Epoch 57/100
# 1327/1327 - 9s - loss: 0.3947 - val_loss: 0.4332 - 9s/epoch - 6ms/step
# Epoch 58/100
# 1327/1327 - 8s - loss: 0.3978 - val_loss: 0.4278 - 8s/epoch - 6ms/step
# Epoch 59/100
# 1327/1327 - 9s - loss: 0.3935 - val_loss: 0.4438 - 9s/epoch - 6ms/step
# Epoch 60/100
# 1327/1327 - 9s - loss: 0.3963 - val_loss: 0.4411 - 9s/epoch - 6ms/step
# Epoch 61/100
# 1327/1327 - 9s - loss: 0.3953 - val_loss: 0.4370 - 9s/epoch - 6ms/step
# Epoch 62/100
# 1327/1327 - 8s - loss: 0.3929 - val_loss: 0.4292 - 8s/epoch - 6ms/step
# Epoch 63/100
# 1327/1327 - 8s - loss: 0.3943 - val_loss: 0.4285 - 8s/epoch - 6ms/step
# Epoch 64/100
# 1327/1327 - 8s - loss: 0.3908 - val_loss: 0.4315 - 8s/epoch - 6ms/step
# Epoch 65/100
# 1327/1327 - 8s - loss: 0.3910 - val_loss: 0.4300 - 8s/epoch - 6ms/step
# Epoch 1/100
# 1327/1327 - 17s - loss: 1.8335 - val_loss: 1.1185 - 17s/epoch - 13ms/step
# Epoch 2/100
# 1327/1327 - 9s - loss: 1.0028 - val_loss: 0.8460 - 9s/epoch - 6ms/step
# Epoch 3/100
# 1327/1327 - 9s - loss: 0.8774 - val_loss: 0.7957 - 9s/epoch - 6ms/step
# Epoch 4/100
# 1327/1327 - 9s - loss: 0.8431 - val_loss: 0.7629 - 9s/epoch - 6ms/step
# Epoch 5/100
# 1327/1327 - 9s - loss: 0.8064 - val_loss: 0.7448 - 9s/epoch - 6ms/step
# Epoch 6/100
# 1327/1327 - 9s - loss: 0.7764 - val_loss: 0.7389 - 9s/epoch - 6ms/step
# Epoch 7/100
# 1327/1327 - 9s - loss: 0.7571 - val_loss: 0.7831 - 9s/epoch - 6ms/step
# Epoch 8/100
# 1327/1327 - 9s - loss: 0.7450 - val_loss: 0.7379 - 9s/epoch - 6ms/step
# Epoch 9/100
# 1327/1327 - 9s - loss: 0.7242 - val_loss: 0.7095 - 9s/epoch - 6ms/step
# Epoch 10/100
# 1327/1327 - 9s - loss: 0.7145 - val_loss: 0.6823 - 9s/epoch - 6ms/step
# Epoch 11/100
# 1327/1327 - 9s - loss: 0.7102 - val_loss: 0.6895 - 9s/epoch - 6ms/step
# Epoch 12/100
# 1327/1327 - 9s - loss: 0.6859 - val_loss: 0.6635 - 9s/epoch - 6ms/step
# Epoch 13/100
# 1327/1327 - 9s - loss: 0.6754 - val_loss: 0.6861 - 9s/epoch - 6ms/step
# Epoch 14/100
# 1327/1327 - 9s - loss: 0.6699 - val_loss: 0.6646 - 9s/epoch - 7ms/step
# Epoch 15/100
# 1327/1327 - 9s - loss: 0.6604 - val_loss: 0.6391 - 9s/epoch - 6ms/step
# Epoch 16/100
# 1327/1327 - 9s - loss: 0.6486 - val_loss: 0.6728 - 9s/epoch - 6ms/step
# Epoch 17/100
# 1327/1327 - 9s - loss: 0.6499 - val_loss: 0.6729 - 9s/epoch - 6ms/step
# Epoch 18/100
# 1327/1327 - 9s - loss: 0.6405 - val_loss: 0.6530 - 9s/epoch - 6ms/step
# Epoch 19/100
# 1327/1327 - 9s - loss: 0.6296 - val_loss: 0.6283 - 9s/epoch - 6ms/step
# Epoch 20/100
# 1327/1327 - 9s - loss: 0.6254 - val_loss: 0.6161 - 9s/epoch - 6ms/step
# Epoch 21/100
# 1327/1327 - 9s - loss: 0.6198 - val_loss: 0.6281 - 9s/epoch - 6ms/step
# Epoch 22/100
# 1327/1327 - 9s - loss: 0.6148 - val_loss: 0.6538 - 9s/epoch - 6ms/step
# Epoch 23/100
# 1327/1327 - 9s - loss: 0.6121 - val_loss: 0.6842 - 9s/epoch - 6ms/step
# Epoch 24/100
# 1327/1327 - 8s - loss: 0.5985 - val_loss: 0.6349 - 8s/epoch - 6ms/step
# Epoch 25/100
# 1327/1327 - 9s - loss: 0.5974 - val_loss: 0.6317 - 9s/epoch - 6ms/step
# Epoch 26/100
# 1327/1327 - 8s - loss: 0.5891 - val_loss: 0.6149 - 8s/epoch - 6ms/step
# Epoch 27/100
# 1327/1327 - 9s - loss: 0.5894 - val_loss: 0.6167 - 9s/epoch - 6ms/step
# Epoch 28/100
# 1327/1327 - 9s - loss: 0.5846 - val_loss: 0.6301 - 9s/epoch - 6ms/step
# Epoch 29/100
# 1327/1327 - 8s - loss: 0.5806 - val_loss: 0.6476 - 8s/epoch - 6ms/step
# Epoch 30/100
# 1327/1327 - 9s - loss: 0.5725 - val_loss: 0.6030 - 9s/epoch - 6ms/step
# Epoch 31/100
# 1327/1327 - 8s - loss: 0.5788 - val_loss: 0.6161 - 8s/epoch - 6ms/step
# Epoch 32/100
# 1327/1327 - 8s - loss: 0.5702 - val_loss: 0.6235 - 8s/epoch - 6ms/step
# Epoch 33/100
# 1327/1327 - 9s - loss: 0.5697 - val_loss: 0.5986 - 9s/epoch - 6ms/step
# Epoch 34/100
# 1327/1327 - 9s - loss: 0.5630 - val_loss: 0.6055 - 9s/epoch - 6ms/step
# Epoch 35/100
# 1327/1327 - 8s - loss: 0.5624 - val_loss: 0.6134 - 8s/epoch - 6ms/step
# Epoch 36/100
# 1327/1327 - 8s - loss: 0.5619 - val_loss: 0.6208 - 8s/epoch - 6ms/step
# Epoch 37/100
# 1327/1327 - 8s - loss: 0.5582 - val_loss: 0.5918 - 8s/epoch - 6ms/step
# Epoch 38/100
# 1327/1327 - 9s - loss: 0.5545 - val_loss: 0.6052 - 9s/epoch - 6ms/step
# Epoch 39/100
# 1327/1327 - 9s - loss: 0.5506 - val_loss: 0.5928 - 9s/epoch - 6ms/step
# Epoch 40/100
# 1327/1327 - 9s - loss: 0.5434 - val_loss: 0.5932 - 9s/epoch - 6ms/step
# Epoch 41/100
# 1327/1327 - 9s - loss: 0.5462 - val_loss: 0.6070 - 9s/epoch - 6ms/step
# Epoch 42/100
# 1327/1327 - 9s - loss: 0.5392 - val_loss: 0.5981 - 9s/epoch - 6ms/step
# Epoch 43/100
# 1327/1327 - 8s - loss: 0.5348 - val_loss: 0.6229 - 8s/epoch - 6ms/step
# Epoch 44/100
# 1327/1327 - 8s - loss: 0.5346 - val_loss: 0.6066 - 8s/epoch - 6ms/step
# Epoch 45/100
# 1327/1327 - 8s - loss: 0.5367 - val_loss: 0.5964 - 8s/epoch - 6ms/step
# Epoch 46/100
# 1327/1327 - 8s - loss: 0.5246 - val_loss: 0.5915 - 8s/epoch - 6ms/step
# Epoch 47/100
# 1327/1327 - 9s - loss: 0.5339 - val_loss: 0.5901 - 9s/epoch - 7ms/step
# Epoch 48/100
# 1327/1327 - 9s - loss: 0.5242 - val_loss: 0.6114 - 9s/epoch - 6ms/step
# Epoch 49/100
# 1327/1327 - 8s - loss: 0.5237 - val_loss: 0.6362 - 8s/epoch - 6ms/step
# Epoch 50/100
# 1327/1327 - 8s - loss: 0.5211 - val_loss: 0.5842 - 8s/epoch - 6ms/step
# Epoch 51/100
# 1327/1327 - 9s - loss: 0.5213 - val_loss: 0.6128 - 9s/epoch - 7ms/step
# Epoch 52/100
# 1327/1327 - 9s - loss: 0.5180 - val_loss: 0.5867 - 9s/epoch - 7ms/step
# Epoch 53/100
# 1327/1327 - 9s - loss: 0.5139 - val_loss: 0.5953 - 9s/epoch - 7ms/step
# Epoch 54/100
# 1327/1327 - 9s - loss: 0.5137 - val_loss: 0.5963 - 9s/epoch - 7ms/step
# Epoch 55/100
# 1327/1327 - 9s - loss: 0.5084 - val_loss: 0.5958 - 9s/epoch - 7ms/step
# Epoch 56/100
# 1327/1327 - 9s - loss: 0.5092 - val_loss: 0.6178 - 9s/epoch - 6ms/step
# Epoch 57/100
# 1327/1327 - 9s - loss: 0.5076 - val_loss: 0.6084 - 9s/epoch - 6ms/step
# Epoch 58/100
# 1327/1327 - 9s - loss: 0.5052 - val_loss: 0.5774 - 9s/epoch - 7ms/step
# Epoch 59/100
# 1327/1327 - 9s - loss: 0.5057 - val_loss: 0.5984 - 9s/epoch - 6ms/step
# Epoch 60/100
# 1327/1327 - 8s - loss: 0.5059 - val_loss: 0.5956 - 8s/epoch - 6ms/step
# Epoch 61/100
# 1327/1327 - 8s - loss: 0.5009 - val_loss: 0.6111 - 8s/epoch - 6ms/step
# Epoch 62/100
# 1327/1327 - 9s - loss: 0.5020 - val_loss: 0.6035 - 9s/epoch - 6ms/step
# Epoch 63/100
# 1327/1327 - 9s - loss: 0.4994 - val_loss: 0.5766 - 9s/epoch - 6ms/step
# Epoch 64/100
# 1327/1327 - 8s - loss: 0.4973 - val_loss: 0.5903 - 8s/epoch - 6ms/step
# Epoch 65/100
# 1327/1327 - 8s - loss: 0.4975 - val_loss: 0.5961 - 8s/epoch - 6ms/step
# Epoch 66/100
# 1327/1327 - 8s - loss: 0.4982 - val_loss: 0.5864 - 8s/epoch - 6ms/step
# Epoch 67/100
# 1327/1327 - 8s - loss: 0.4867 - val_loss: 0.5942 - 8s/epoch - 6ms/step
# Epoch 68/100
# 1327/1327 - 8s - loss: 0.4934 - val_loss: 0.5976 - 8s/epoch - 6ms/step
# Epoch 69/100
# 1327/1327 - 8s - loss: 0.4875 - val_loss: 0.5876 - 8s/epoch - 6ms/step
# Epoch 70/100
# 1327/1327 - 8s - loss: 0.4868 - val_loss: 0.6000 - 8s/epoch - 6ms/step
# Epoch 71/100
# 1327/1327 - 8s - loss: 0.4878 - val_loss: 0.6104 - 8s/epoch - 6ms/step
# Epoch 72/100
# 1327/1327 - 8s - loss: 0.4835 - val_loss: 0.6080 - 8s/epoch - 6ms/step
# Epoch 73/100
# 1327/1327 - 8s - loss: 0.4838 - val_loss: 0.5976 - 8s/epoch - 6ms/step
# 100%|██████████| 1/1 [5:33:51<00:00, 20031.59s/it]
